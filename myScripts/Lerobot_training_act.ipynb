# %% [markdown]
# # 🤗 x 🦾: Training ACT with LeRobot Notebook
#
# Welcome to the **LeRobot ACT training notebook**! This notebook provides a ready-to-run setup for training imitation learning policies using the [🤗 LeRobot](https://github.com/huggingface/lerobot) library.
#
# In this example, we train an `ACT` policy using a dataset hosted on the [Hugging Face Hub](https://huggingface.co/), and optionally track training metrics with [Weights & Biases (wandb)](https://wandb.ai/).
#
# ## ⚙️ Requirements
# - A Hugging Face dataset repo ID containing your training data (`--dataset.repo_id=YOUR_USERNAME/YOUR_DATASET`)
# - Optional: A [wandb](https://wandb.ai/) account if you want to enable training visualization
# - Recommended: GPU runtime (e.g., NVIDIA A100) for faster training
#
# ## ⏱️ Expected Training Time
# Training with the `ACT` policy for 100,000 steps typically takes **about 1.5 hours on an NVIDIA A100** GPU. On less powerful GPUs or CPUs, training may take significantly longer.
#
# ## Example Output
# Model checkpoints, logs, and training plots will be saved to the specified `--output_dir`. If `wandb` is enabled, progress will also be visualized in your wandb project dashboard.

# %% [markdown]
# ## Install conda
# This cell uses `condacolab` to bootstrap a full Conda environment inside Google Colab.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:06
# 🔁 Restarting kernel...

# %% [markdown]
# ## Install LeRobot
# This cell clones the `lerobot` repository from Hugging Face, installs FFmpeg (version 7.1.1), and installs the package in editable mode.

# %%
# !git clone https://github.com/huggingface/lerobot.git
# !conda install ffmpeg=7.1.1 -c conda-forge
# !cd lerobot && pip install -e .
# Out:
# Cloning into 'lerobot'...
# remote: Enumerating objects: 41303, done.
# remote: Counting objects: 100% (228/228), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 41303 (delta 188), reused 97 (delta 97), pack-reused 41075 (from 4)
# Receiving objects: 100% (41303/41303), 201.89 MiB | 38.92 MiB/s, done.
# Resolving deltas: 100% (26849/26849), done.
# Filtering content: 100% (45/45), 69.03 MiB | 50.06 MiB/s, done.
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - ffmpeg=7.1.1
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alsa-lib-1.2.14            |       hb9d3cd8_0         553 KB  conda-forge
#     aom-3.9.1                  |       hac33072_0         2.6 MB  conda-forge
#     attr-2.5.2                 |       h39aace5_0          66 KB  conda-forge
#     ca-certificates-2025.10.5  |       hbd8a1cb_0         152 KB  conda-forge
#     cairo-1.18.4               |       h3394656_0         955 KB  conda-forge
#     certifi-2025.10.5          |     pyhd8ed1ab_0         156 KB  conda-forge
#     conda-24.11.3              |  py311h38be061_0         1.1 MB  conda-forge
#     dav1d-1.2.1                |       hd590300_0         742 KB  conda-forge
#     dbus-1.16.2                |       h3c4dab8_0         428 KB  conda-forge
#     ffmpeg-7.1.1               | gpl_h5c0ada0_711        10.1 MB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_3         1.5 MB  conda-forge
#     fontconfig-2.15.0          |       h7e30c49_1         259 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |       hc364b38_1           4 KB  conda-forge
#     freetype-2.14.1            |       ha770c72_0         169 KB  conda-forge
#     fribidi-1.0.16             |       hb03c661_0          60 KB  conda-forge
#     gdk-pixbuf-2.44.4          |       h2b0a6b4_0         559 KB  conda-forge
#     gettext-0.25.1             |       h3f43e3d_1         529 KB  conda-forge
#     gettext-tools-0.25.1       |       h3f43e3d_1         3.5 MB  conda-forge
#     gmp-6.3.0                  |       hac33072_2         449 KB  conda-forge
#     graphite2-1.3.14           |       hecca717_2          97 KB  conda-forge
#     harfbuzz-12.2.0            |       h15599e2_0         2.3 MB  conda-forge
#     icu-75.1                   |       he02047a_0        11.6 MB  conda-forge
#     intel-gmmlib-22.8.2        |       hb700be7_0         976 KB  conda-forge
#     intel-media-driver-25.3.4  |       hecca717_0         8.0 MB  conda-forge
#     lame-3.100                 |    h166bdaf_1003         496 KB  conda-forge
#     lerc-4.0.0                 |       h0aef613_1         258 KB  conda-forge
#     level-zero-1.26.0          |       hb700be7_0         624 KB  conda-forge
#     libabseil-20250512.1       | cxx17_hba17884_0         1.2 MB  conda-forge
#     libasprintf-0.25.1         |       h3f43e3d_1          52 KB  conda-forge
#     libasprintf-devel-0.25.1   |       h3f43e3d_1          34 KB  conda-forge
#     libass-0.17.4              |       h96ad9f0_0         149 KB  conda-forge
#     libcap-2.76                |       h0b2e76d_0         119 KB  conda-forge
#     libdeflate-1.25            |       h17f619e_0          72 KB  conda-forge
#     libdrm-2.4.125             |       hb03c661_1         304 KB  conda-forge
#     libegl-1.7.0               |       ha4b6fd6_2          44 KB  conda-forge
#     libexpat-2.7.1             |       hecca717_0          73 KB  conda-forge
#     libffi-3.5.2               |       h9ec8514_0          56 KB  conda-forge
#     libflac-1.4.3              |       h59595ed_0         385 KB  conda-forge
#     libfreetype-2.14.1         |       ha770c72_0           7 KB  conda-forge
#     libfreetype6-2.14.1        |       h73754d4_0         378 KB  conda-forge
#     libgettextpo-0.25.1        |       h3f43e3d_1         184 KB  conda-forge
#     libgettextpo-devel-0.25.1  |       h3f43e3d_1          37 KB  conda-forge
#     libgl-1.7.0                |       ha4b6fd6_2         132 KB  conda-forge
#     libglib-2.86.1             |       h32235b2_2         3.8 MB  conda-forge
#     libglvnd-1.7.0             |       ha4b6fd6_2         129 KB  conda-forge
#     libglx-1.7.0               |       ha4b6fd6_2          74 KB  conda-forge
#     libhwloc-2.12.1            |default_h7f8ec31_1002         2.3 MB  conda-forge
#     libiconv-1.18              |       h3b78370_2         772 KB  conda-forge
#     libjpeg-turbo-3.1.2        |       hb03c661_0         619 KB  conda-forge
#     liblzma-5.8.1              |       hb9d3cd8_2         110 KB  conda-forge
#     libogg-1.3.5               |       hd0c01bc_1         213 KB  conda-forge
#     libopenvino-2025.2.0       |       hb617929_1         6.0 MB  conda-forge
#     libopenvino-auto-batch-plugin-2025.2.0|       hed573e4_1         112 KB  conda-forge
#     libopenvino-auto-plugin-2025.2.0|       hed573e4_1         245 KB  conda-forge
#     libopenvino-hetero-plugin-2025.2.0|       hd41364c_1         190 KB  conda-forge
#     libopenvino-intel-cpu-plugin-2025.2.0|       hb617929_1        11.8 MB  conda-forge
#     libopenvino-intel-gpu-plugin-2025.2.0|       hb617929_1        10.3 MB  conda-forge
#     libopenvino-intel-npu-plugin-2025.2.0|       hb617929_1         1.2 MB  conda-forge
#     libopenvino-ir-frontend-2025.2.0|       hd41364c_1         200 KB  conda-forge
#     libopenvino-onnx-frontend-2025.2.0|       h1862bb8_1         1.6 MB  conda-forge
#     libopenvino-paddle-frontend-2025.2.0|       h1862bb8_1         727 KB  conda-forge
#     libopenvino-pytorch-frontend-2025.2.0|       hecca717_1         1.2 MB  conda-forge
#     libopenvino-tensorflow-frontend-2025.2.0|       h0767aad_1         1.3 MB  conda-forge
#     libopenvino-tensorflow-lite-frontend-2025.2.0|       hecca717_1         485 KB  conda-forge
#     libopus-1.5.2              |       hd0c01bc_0         305 KB  conda-forge
#     libpciaccess-0.18          |       hb9d3cd8_0          28 KB  conda-forge
#     libpng-1.6.50              |       h421ea60_1         310 KB  conda-forge
#     libprotobuf-6.31.1         |       h49aed37_2         4.4 MB  conda-forge
#     librsvg-2.60.0             |       h61e6d4b_0         3.3 MB  conda-forge
#     libsndfile-1.2.2           |       hc60ed4a_1         346 KB  conda-forge
#     libsystemd0-258.2          |       h07e904d_0         510 KB  conda-forge
#     libtiff-4.7.1              |       h9d88235_1         425 KB  conda-forge
#     libudev1-258.2             |       h07e904d_0         162 KB  conda-forge
#     libunwind-1.8.3            |       h65a8314_0          74 KB  conda-forge
#     liburing-2.12              |       hb700be7_0         125 KB  conda-forge
#     libusb-1.0.29              |       h73b1eb8_0          87 KB  conda-forge
#     libva-2.22.0               |       h4f16b4b_2         212 KB  conda-forge
#     libvorbis-1.3.7            |       h54a6638_2         279 KB  conda-forge
#     libvpl-2.15.0              |       h54a6638_1         281 KB  conda-forge
#     libvpx-1.14.1              |       hac33072_0         999 KB  conda-forge
#     libvulkan-loader-1.4.328.1 |       h5279c79_0         193 KB  conda-forge
#     libwebp-base-1.6.0         |       hd42ef1d_0         419 KB  conda-forge
#     libxcb-1.17.0              |       h8a09558_0         387 KB  conda-forge
#     libxkbcommon-1.13.0        |       hca5e8e5_0         824 KB  conda-forge
#     libxml2-2.15.1             |       h26afc86_0          44 KB  conda-forge
#     libxml2-16-2.15.1          |       ha9997c6_0         543 KB  conda-forge
#     mpg123-1.32.9              |       hc50e24c_0         480 KB  conda-forge
#     ocl-icd-2.3.3              |       hb9d3cd8_0         104 KB  conda-forge
#     opencl-headers-2025.06.13  |       h5888daf_0          54 KB  conda-forge
#     openh264-2.6.0             |       hc22cd8d_0         714 KB  conda-forge
#     openssl-3.6.0              |       h26f9b46_0         3.0 MB  conda-forge
#     pango-1.56.4               |       hadf4263_0         445 KB  conda-forge
#     pcre2-10.46                |       h1321c63_0         1.2 MB  conda-forge
#     pixman-0.46.4              |       h54a6638_1         440 KB  conda-forge
#     pthread-stubs-0.4          |    hb9d3cd8_1002           8 KB  conda-forge
#     pugixml-1.15               |       h3f63f65_0         116 KB  conda-forge
#     pulseaudio-client-17.0     |       h9a8bead_2         744 KB  conda-forge
#     sdl2-2.32.56               |       h54a6638_0         575 KB  conda-forge
#     sdl3-3.2.26                |       h68140b3_0         1.8 MB  conda-forge
#     snappy-1.2.2               |       h03e3b7b_0          45 KB  conda-forge
#     svt-av1-3.1.2              |       hecca717_0         2.6 MB  conda-forge
#     tbb-2022.3.0               |       h8d10470_1         177 KB  conda-forge
#     wayland-1.24.0             |       hd6090a7_1         322 KB  conda-forge
#     wayland-protocols-1.45     |       hd8ed1ab_0         135 KB  conda-forge
#     x264-1!164.3095            |       h166bdaf_2         877 KB  conda-forge
#     x265-3.5                   |       h924138e_3         3.2 MB  conda-forge
#     xkeyboard-config-2.46      |       hb03c661_0         388 KB  conda-forge
#     xorg-libice-1.1.2          |       hb9d3cd8_0          57 KB  conda-forge
#     xorg-libsm-1.2.6           |       he73a12e_0          27 KB  conda-forge
#     xorg-libx11-1.8.12         |       h4f16b4b_0         816 KB  conda-forge
#     xorg-libxau-1.0.12         |       hb9d3cd8_0          14 KB  conda-forge
#     xorg-libxcursor-1.2.3      |       hb9d3cd8_0          32 KB  conda-forge
#     xorg-libxdmcp-1.1.5        |       hb9d3cd8_0          19 KB  conda-forge
#     xorg-libxext-1.3.6         |       hb9d3cd8_0          49 KB  conda-forge
#     xorg-libxfixes-6.0.2       |       hb03c661_0          20 KB  conda-forge
#     xorg-libxrandr-1.5.4       |       hb9d3cd8_0          29 KB  conda-forge
#     xorg-libxrender-0.9.12     |       hb9d3cd8_0          32 KB  conda-forge
#     xorg-libxscrnsaver-1.2.4   |       hb9d3cd8_0          14 KB  conda-forge
#     zstandard-0.25.0           |  py311haee01d2_1         456 KB  conda-forge
#     zstd-1.5.7                 |       hb8e6e7a_2         554 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       129.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   alsa-lib           conda-forge/linux-64::alsa-lib-1.2.14-hb9d3cd8_0
#   aom                conda-forge/linux-64::aom-3.9.1-hac33072_0
#   attr               conda-forge/linux-64::attr-2.5.2-h39aace5_0
#   cairo              conda-forge/linux-64::cairo-1.18.4-h3394656_0
#   dav1d              conda-forge/linux-64::dav1d-1.2.1-hd590300_0
#   dbus               conda-forge/linux-64::dbus-1.16.2-h3c4dab8_0
#   ffmpeg             conda-forge/linux-64::ffmpeg-7.1.1-gpl_h5c0ada0_711
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fontconfig         conda-forge/linux-64::fontconfig-2.15.0-h7e30c49_1
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-hc364b38_1
#   freetype           conda-forge/linux-64::freetype-2.14.1-ha770c72_0
#   fribidi            conda-forge/linux-64::fribidi-1.0.16-hb03c661_0
#   gdk-pixbuf         conda-forge/linux-64::gdk-pixbuf-2.44.4-h2b0a6b4_0
#   gettext            conda-forge/linux-64::gettext-0.25.1-h3f43e3d_1
#   gettext-tools      conda-forge/linux-64::gettext-tools-0.25.1-h3f43e3d_1
#   gmp                conda-forge/linux-64::gmp-6.3.0-hac33072_2
#   graphite2          conda-forge/linux-64::graphite2-1.3.14-hecca717_2
#   harfbuzz           conda-forge/linux-64::harfbuzz-12.2.0-h15599e2_0
#   icu                conda-forge/linux-64::icu-75.1-he02047a_0
#   intel-gmmlib       conda-forge/linux-64::intel-gmmlib-22.8.2-hb700be7_0
#   intel-media-driver conda-forge/linux-64::intel-media-driver-25.3.4-hecca717_0
#   lame               conda-forge/linux-64::lame-3.100-h166bdaf_1003
#   lerc               conda-forge/linux-64::lerc-4.0.0-h0aef613_1
#   level-zero         conda-forge/linux-64::level-zero-1.26.0-hb700be7_0
#   libabseil          conda-forge/linux-64::libabseil-20250512.1-cxx17_hba17884_0
#   libasprintf        conda-forge/linux-64::libasprintf-0.25.1-h3f43e3d_1
#   libasprintf-devel  conda-forge/linux-64::libasprintf-devel-0.25.1-h3f43e3d_1
#   libass             conda-forge/linux-64::libass-0.17.4-h96ad9f0_0
#   libcap             conda-forge/linux-64::libcap-2.76-h0b2e76d_0
#   libdeflate         conda-forge/linux-64::libdeflate-1.25-h17f619e_0
#   libdrm             conda-forge/linux-64::libdrm-2.4.125-hb03c661_1
#   libegl             conda-forge/linux-64::libegl-1.7.0-ha4b6fd6_2
#   libflac            conda-forge/linux-64::libflac-1.4.3-h59595ed_0
#   libfreetype        conda-forge/linux-64::libfreetype-2.14.1-ha770c72_0
#   libfreetype6       conda-forge/linux-64::libfreetype6-2.14.1-h73754d4_0
#   libgettextpo       conda-forge/linux-64::libgettextpo-0.25.1-h3f43e3d_1
#   libgettextpo-devel conda-forge/linux-64::libgettextpo-devel-0.25.1-h3f43e3d_1
#   libgl              conda-forge/linux-64::libgl-1.7.0-ha4b6fd6_2
#   libglib            conda-forge/linux-64::libglib-2.86.1-h32235b2_2
#   libglvnd           conda-forge/linux-64::libglvnd-1.7.0-ha4b6fd6_2
#   libglx             conda-forge/linux-64::libglx-1.7.0-ha4b6fd6_2
#   libhwloc           conda-forge/linux-64::libhwloc-2.12.1-default_h7f8ec31_1002
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-3.1.2-hb03c661_0
#   libogg             conda-forge/linux-64::libogg-1.3.5-hd0c01bc_1
#   libopenvino        conda-forge/linux-64::libopenvino-2025.2.0-hb617929_1
#   libopenvino-auto-~ conda-forge/linux-64::libopenvino-auto-batch-plugin-2025.2.0-hed573e4_1
#   libopenvino-auto-~ conda-forge/linux-64::libopenvino-auto-plugin-2025.2.0-hed573e4_1
#   libopenvino-heter~ conda-forge/linux-64::libopenvino-hetero-plugin-2025.2.0-hd41364c_1
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-cpu-plugin-2025.2.0-hb617929_1
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-gpu-plugin-2025.2.0-hb617929_1
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-npu-plugin-2025.2.0-hb617929_1
#   libopenvino-ir-fr~ conda-forge/linux-64::libopenvino-ir-frontend-2025.2.0-hd41364c_1
#   libopenvino-onnx-~ conda-forge/linux-64::libopenvino-onnx-frontend-2025.2.0-h1862bb8_1
#   libopenvino-paddl~ conda-forge/linux-64::libopenvino-paddle-frontend-2025.2.0-h1862bb8_1
#   libopenvino-pytor~ conda-forge/linux-64::libopenvino-pytorch-frontend-2025.2.0-hecca717_1
#   libopenvino-tenso~ conda-forge/linux-64::libopenvino-tensorflow-frontend-2025.2.0-h0767aad_1
#   libopenvino-tenso~ conda-forge/linux-64::libopenvino-tensorflow-lite-frontend-2025.2.0-hecca717_1
#   libopus            conda-forge/linux-64::libopus-1.5.2-hd0c01bc_0
#   libpciaccess       conda-forge/linux-64::libpciaccess-0.18-hb9d3cd8_0
#   libpng             conda-forge/linux-64::libpng-1.6.50-h421ea60_1
#   libprotobuf        conda-forge/linux-64::libprotobuf-6.31.1-h49aed37_2
#   librsvg            conda-forge/linux-64::librsvg-2.60.0-h61e6d4b_0
#   libsndfile         conda-forge/linux-64::libsndfile-1.2.2-hc60ed4a_1
#   libsystemd0        conda-forge/linux-64::libsystemd0-258.2-h07e904d_0
#   libtiff            conda-forge/linux-64::libtiff-4.7.1-h9d88235_1
#   libudev1           conda-forge/linux-64::libudev1-258.2-h07e904d_0
#   libunwind          conda-forge/linux-64::libunwind-1.8.3-h65a8314_0
#   liburing           conda-forge/linux-64::liburing-2.12-hb700be7_0
#   libusb             conda-forge/linux-64::libusb-1.0.29-h73b1eb8_0
#   libva              conda-forge/linux-64::libva-2.22.0-h4f16b4b_2
#   libvorbis          conda-forge/linux-64::libvorbis-1.3.7-h54a6638_2
#   libvpl             conda-forge/linux-64::libvpl-2.15.0-h54a6638_1
#   libvpx             conda-forge/linux-64::libvpx-1.14.1-hac33072_0
#   libvulkan-loader   conda-forge/linux-64::libvulkan-loader-1.4.328.1-h5279c79_0
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.6.0-hd42ef1d_0
#   libxcb             conda-forge/linux-64::libxcb-1.17.0-h8a09558_0
#   libxkbcommon       conda-forge/linux-64::libxkbcommon-1.13.0-hca5e8e5_0
#   libxml2-16         conda-forge/linux-64::libxml2-16-2.15.1-ha9997c6_0
#   mpg123             conda-forge/linux-64::mpg123-1.32.9-hc50e24c_0
#   ocl-icd            conda-forge/linux-64::ocl-icd-2.3.3-hb9d3cd8_0
#   opencl-headers     conda-forge/linux-64::opencl-headers-2025.06.13-h5888daf_0
#   openh264           conda-forge/linux-64::openh264-2.6.0-hc22cd8d_0
#   pango              conda-forge/linux-64::pango-1.56.4-hadf4263_0
#   pcre2              conda-forge/linux-64::pcre2-10.46-h1321c63_0
#   pixman             conda-forge/linux-64::pixman-0.46.4-h54a6638_1
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-hb9d3cd8_1002
#   pugixml            conda-forge/linux-64::pugixml-1.15-h3f63f65_0
#   pulseaudio-client  conda-forge/linux-64::pulseaudio-client-17.0-h9a8bead_2
#   sdl2               conda-forge/linux-64::sdl2-2.32.56-h54a6638_0
#   sdl3               conda-forge/linux-64::sdl3-3.2.26-h68140b3_0
#   snappy             conda-forge/linux-64::snappy-1.2.2-h03e3b7b_0
#   svt-av1            conda-forge/linux-64::svt-av1-3.1.2-hecca717_0
#   tbb                conda-forge/linux-64::tbb-2022.3.0-h8d10470_1
#   wayland            conda-forge/linux-64::wayland-1.24.0-hd6090a7_1
#   wayland-protocols  conda-forge/noarch::wayland-protocols-1.45-hd8ed1ab_0
#   x264               conda-forge/linux-64::x264-1!164.3095-h166bdaf_2
#   x265               conda-forge/linux-64::x265-3.5-h924138e_3
#   xkeyboard-config   conda-forge/linux-64::xkeyboard-config-2.46-hb03c661_0
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.1.2-hb9d3cd8_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.6-he73a12e_0
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.8.12-h4f16b4b_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.12-hb9d3cd8_0
#   xorg-libxcursor    conda-forge/linux-64::xorg-libxcursor-1.2.3-hb9d3cd8_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.5-hb9d3cd8_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.6-hb9d3cd8_0
#   xorg-libxfixes     conda-forge/linux-64::xorg-libxfixes-6.0.2-hb03c661_0
#   xorg-libxrandr     conda-forge/linux-64::xorg-libxrandr-1.5.4-hb9d3cd8_0
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.12-hb9d3cd8_0
#   xorg-libxscrnsaver conda-forge/linux-64::xorg-libxscrnsaver-1.2.4-hb9d3cd8_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge/linux-64::ca-certificates~ --> conda-forge/noarch::ca-certificates-2025.10.5-hbd8a1cb_0
#   certifi                           2024.12.14-pyhd8ed1ab_0 --> 2025.10.5-pyhd8ed1ab_0
#   conda                             24.11.2-py311h38be061_1 --> 24.11.3-py311h38be061_0
#   libexpat                                 2.6.4-h5888daf_0 --> 2.7.1-hecca717_0
#   libffi                                   3.4.2-h7f98852_5 --> 3.5.2-h9ec8514_0
#   libiconv                                  1.17-hd590300_2 --> 1.18-h3b78370_2
#   liblzma                                  5.6.3-hb9d3cd8_1 --> 5.8.1-hb9d3cd8_2
#   libxml2                                 2.13.5-h0d44e9d_1 --> 2.15.1-h26afc86_0
#   openssl                                  3.4.0-h7b32b05_1 --> 3.6.0-h26f9b46_0
#   zstandard                          0.23.0-py311hbc35293_1 --> 0.25.0-py311haee01d2_1
#   zstd                                     1.5.6-ha6fb4c9_0 --> 1.5.7-hb8e6e7a_2
#
#
#
# Downloading and Extracting Packages:
# libopenvino-intel-cp | 11.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
# icu-75.1             | 11.6 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# libopenvino-intel-gp | 10.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
# ffmpeg-7.1.1         | 10.1 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# intel-media-driver-2 | 8.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# libopenvino-2025.2.0 | 6.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# libprotobuf-6.31.1   | 4.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# libglib-2.86.1       | 3.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# gettext-tools-0.25.1 | 3.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# librsvg-2.60.0       | 3.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# openssl-3.6.0        | 3.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.1.2        | 2.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# aom-3.9.1            | 2.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-12.2.0      | 2.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sdl3-3.2.26          | 1.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-intel-cp | 11.8 MB   | :  30% 0.30180211041206423/1 [00:00<00:00,  3.01it/s]
# icu-75.1             | 11.6 MB   | :  10% 0.10266000165056187/1 [00:00<00:00,  1.02it/s]
#
# libopenvino-intel-gp | 10.3 MB   | :  11% 0.11058519825287458/1 [00:00<00:00,  1.10it/s]
#
#
# ffmpeg-7.1.1         | 10.1 MB   | :   2% 0.020202455174237546/1 [00:00<00:04,  4.96s/it]
#
#
#
# libopenvino-intel-cp | 11.8 MB   | :  72% 0.7240603262956102/1 [00:00<00:00,  3.72it/s]
# icu-75.1             | 11.6 MB   | :  43% 0.4295510595378773/1 [00:00<00:00,  2.34it/s]
#
# libopenvino-intel-gp | 10.3 MB   | :  58% 0.5801935743952187/1 [00:00<00:00,  3.21it/s]
#
#
# ffmpeg-7.1.1         | 10.1 MB   | :  44% 0.43823787377961443/1 [00:00<00:00,  2.54it/s]
#
#
#
# intel-media-driver-2 | 8.0 MB    | :  81% 0.8129173932087064/1 [00:00<00:00,  4.40it/s]
# icu-75.1             | 11.6 MB   | :  86% 0.8591021190757546/1 [00:00<00:00,  3.23it/s]
#
#
# ffmpeg-7.1.1         | 10.1 MB   | :  97% 0.971271883376805/1 [00:00<00:00,  3.81it/s]
#
#
#
# intel-media-driver-2 | 8.0 MB    | : 100% 1.0/1 [00:00<00:00,  4.40it/s]
#
# libopenvino-intel-gp | 10.3 MB   | : 100% 1.0/1 [00:00<00:00,  2.81it/s]
#
# libopenvino-intel-gp | 10.3 MB   | : 100% 1.0/1 [00:00<00:00,  2.81it/s]
#
#
#
#
# libopenvino-2025.2.0 | 6.0 MB    | :   0% 0.0026236350380182075/1 [00:00<02:22, 142.47s/it]
#
#
# libopenvino-intel-cp | 11.8 MB   | : 100% 1.0/1 [00:00<00:00,  3.72it/s]
#
#
#
#
#
# libprotobuf-6.31.1   | 4.4 MB    | :   0% 0.003526568509361851/1 [00:00<01:52, 112.53s/it]
#
#
#
#
#
#
# libglib-2.86.1       | 3.8 MB    | :   0% 0.0041650280511487/1 [00:00<01:40, 101.07s/it]
#
#
#
#
#
#
#
# gettext-tools-0.25.1 | 3.5 MB    | :   0% 0.00449603098485416/1 [00:00<01:33, 94.13s/it]
# icu-75.1             | 11.6 MB   | : 100% 1.0/1 [00:00<00:00,  3.23it/s]
#
#
#
#
# libopenvino-2025.2.0 | 6.0 MB    | :  73% 0.7267469055310435/1 [00:00<00:00,  2.01it/s]
#
#
#
#
#
#
#
#
# librsvg-2.60.0       | 3.3 MB    | :   0% 0.004787875546796486/1 [00:00<01:40, 101.14s/it]
#
#
#
#
#
# libprotobuf-6.31.1   | 4.4 MB    | :  92% 0.923960949452805/1 [00:00<00:00,  2.44it/s]
#
#
#
#
#
#
# libglib-2.86.1       | 3.8 MB    | :  79% 0.7871903016671044/1 [00:00<00:00,  1.99it/s]
#
#
#
#
#
#
#
# gettext-tools-0.25.1 | 3.5 MB    | :  87% 0.8722300110617071/1 [00:00<00:00,  2.20it/s]
#
#
#
#
#
# libprotobuf-6.31.1   | 4.4 MB    | : 100% 1.0/1 [00:00<00:00,  2.44it/s]
#
#
#
#
#
#
#
# gettext-tools-0.25.1 | 3.5 MB    | : 100% 1.0/1 [00:00<00:00,  2.20it/s]
#
#
#
#
#
#
# libglib-2.86.1       | 3.8 MB    | : 100% 1.0/1 [00:00<00:00,  1.99it/s]
#
#
#
#
#
#
#
#
# librsvg-2.60.0       | 3.3 MB    | : 100% 1.0/1 [00:00<00:00,  2.08it/s]
#
#
#
#
#
#
#
#
# librsvg-2.60.0       | 3.3 MB    | : 100% 1.0/1 [00:00<00:00,  2.08it/s]
#
#
#
#
# libopenvino-2025.2.0 | 6.0 MB    | : 100% 1.0/1 [00:00<00:00,  2.01it/s]
#
#
#
#
#
#
#
#
#
#
# openssl-3.6.0        | 3.0 MB    | :   1% 0.005175966758061148/1 [00:00<02:03, 123.84s/it]
#
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | :   0% 0.004880274801411181/1 [00:00<02:12, 133.64s/it]
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.1.2        | 2.6 MB    | :   1% 0.005976944403910696/1 [00:00<01:49, 110.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# aom-3.9.1            | 2.6 MB    | :   1% 0.006053807351178468/1 [00:00<01:49, 110.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | :   1% 0.006685595039993602/1 [00:00<01:40, 101.15s/it]
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.1.2        | 2.6 MB    | : 100% 1.0/1 [00:00<00:00,  1.73it/s]
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.1.2        | 2.6 MB    | : 100% 1.0/1 [00:00<00:00,  1.73it/s]
#
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.66it/s]
#
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.66it/s]
#
#
#
#
#
#
#
#
#
#
# openssl-3.6.0        | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.64it/s]
#
#
#
#
#
#
#
#
#
#
# openssl-3.6.0        | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.64it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | : 100% 1.0/1 [00:00<00:00,  1.65it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | : 100% 1.0/1 [00:00<00:00,  1.65it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# aom-3.9.1            | 2.6 MB    | : 100% 1.0/1 [00:00<00:00,  1.63it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# aom-3.9.1            | 2.6 MB    | : 100% 1.0/1 [00:00<00:00,  1.63it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-12.2.0      | 2.3 MB    | :   1% 0.006794370757665231/1 [00:00<01:58, 119.76s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sdl3-3.2.26          | 1.8 MB    | :   1% 0.008461446295844884/1 [00:00<01:37, 98.70s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.6 MB    | :   1% 0.00950070832002032/1 [00:00<01:27, 88.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | :   1% 0.010110434778315882/1 [00:00<01:23, 84.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-12.2.0      | 2.3 MB    | : 100% 1.0/1 [00:00<00:00, 119.76s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.6 MB    | : 100% 1.0/1 [00:00<00:00, 88.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | : 100% 1.0/1 [00:00<00:00, 84.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sdl3-3.2.26          | 1.8 MB    | : 100% 1.0/1 [00:00<00:00, 98.70s/it]
#
#
#
# intel-media-driver-2 | 8.0 MB    | : 100% 1.0/1 [00:01<00:00,  4.40it/s]
#
# libopenvino-intel-gp | 10.3 MB   | : 100% 1.0/1 [00:01<00:00,  2.81it/s]
#
#
# ffmpeg-7.1.1         | 10.1 MB   | : 100% 1.0/1 [00:01<00:00,  3.81it/s]
#
#
#
#
#
# libopenvino-intel-cp | 11.8 MB   | : 100% 1.0/1 [00:01<00:00,  3.72it/s]
# icu-75.1             | 11.6 MB   | : 100% 1.0/1 [00:01<00:00,  3.23it/s]
#
#
#
#
#
#
#
#
# librsvg-2.60.0       | 3.3 MB    | : 100% 1.0/1 [00:02<00:00,  2.08it/s]
#
#
#
#
#
#
#
# gettext-tools-0.25.1 | 3.5 MB    | : 100% 1.0/1 [00:02<00:00,  2.20it/s]
#
#
#
#
#
#
# libglib-2.86.1       | 3.8 MB    | : 100% 1.0/1 [00:02<00:00,  1.99it/s]
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.1.2        | 2.6 MB    | : 100% 1.0/1 [00:02<00:00,  1.73it/s]
#
#
#
#
# libopenvino-2025.2.0 | 6.0 MB    | : 100% 1.0/1 [00:02<00:00,  2.01it/s]
#
#
#
#
#
#
#
#
#
#
# openssl-3.6.0        | 3.0 MB    | : 100% 1.0/1 [00:02<00:00,  1.64it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | : 100% 1.0/1 [00:02<00:00,  1.65it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# aom-3.9.1            | 2.6 MB    | : 100% 1.0/1 [00:02<00:00,  1.63it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.6 MB    | : 100% 1.0/1 [00:02<00:00,  2.32s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.6 MB    | : 100% 1.0/1 [00:02<00:00,  2.32s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | : 100% 1.0/1 [00:02<00:00,  2.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | : 100% 1.0/1 [00:02<00:00,  2.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-12.2.0      | 2.3 MB    | : 100% 1.0/1 [00:02<00:00,  2.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-12.2.0      | 2.3 MB    | : 100% 1.0/1 [00:02<00:00,  2.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sdl3-3.2.26          | 1.8 MB    | : 100% 1.0/1 [00:02<00:00,  2.50s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sdl3-3.2.26          | 1.8 MB    | : 100% 1.0/1 [00:02<00:00,  2.50s/it]
#
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | : 100% 1.0/1 [00:03<00:00,  1.66it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# /
# \
# done
# Obtaining file:///content/lerobot
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Collecting datasets<4.2.0,>=4.0.0 (from lerobot==0.4.1)
#   Downloading datasets-4.1.1-py3-none-any.whl.metadata (18 kB)
# Collecting diffusers<0.36.0,>=0.27.2 (from lerobot==0.4.1)
#   Downloading diffusers-0.35.2-py3-none-any.whl.metadata (20 kB)
# Collecting huggingface-hub<0.36.0,>=0.34.2 (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1)
#   Downloading huggingface_hub-0.35.3-py3-none-any.whl.metadata (14 kB)
# Collecting accelerate<2.0.0,>=1.10.0 (from lerobot==0.4.1)
#   Downloading accelerate-1.11.0-py3-none-any.whl.metadata (19 kB)
# Collecting setuptools<81.0.0,>=71.0.0 (from lerobot==0.4.1)
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting cmake<4.2.0,>=3.29.0.1 (from lerobot==0.4.1)
#   Downloading cmake-4.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.5 kB)
# Collecting einops<0.9.0,>=0.8.0 (from lerobot==0.4.1)
#   Downloading einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting opencv-python-headless<4.13.0,>=4.9.0 (from lerobot==0.4.1)
#   Downloading opencv_python_headless-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Collecting av<16.0.0,>=15.0.0 (from lerobot==0.4.1)
#   Downloading av-15.1.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Collecting jsonlines<5.0.0,>=4.0.0 (from lerobot==0.4.1)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: packaging<26.0,>=24.2 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (24.2)
# Collecting pynput<1.9.0,>=1.7.7 (from lerobot==0.4.1)
#   Downloading pynput-1.8.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting pyserial<4.0,>=3.5 (from lerobot==0.4.1)
#   Downloading pyserial-3.5-py2.py3-none-any.whl.metadata (1.6 kB)
# Collecting wandb<0.22.0,>=0.20.0 (from lerobot==0.4.1)
#   Downloading wandb-0.21.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting torch<2.8.0,>=2.2.1 (from lerobot==0.4.1)
#   Downloading torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting torchcodec<0.6.0,>=0.2.1 (from lerobot==0.4.1)
#   Downloading torchcodec-0.5-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting torchvision<0.23.0,>=0.21.0 (from lerobot==0.4.1)
#   Downloading torchvision-0.22.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Collecting draccus==0.10.0 (from lerobot==0.4.1)
#   Downloading draccus-0.10.0-py3-none-any.whl.metadata (24 kB)
# Collecting gymnasium<2.0.0,>=1.1.1 (from lerobot==0.4.1)
#   Downloading gymnasium-1.2.2-py3-none-any.whl.metadata (10 kB)
# Collecting rerun-sdk<0.27.0,>=0.24.0 (from lerobot==0.4.1)
#   Downloading rerun_sdk-0.26.2-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Collecting deepdiff<9.0.0,>=7.0.1 (from lerobot==0.4.1)
#   Downloading deepdiff-8.6.1-py3-none-any.whl.metadata (8.6 kB)
# Collecting imageio<3.0.0,>=2.34.0 (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.4.1)
#   Downloading imageio-2.37.2-py3-none-any.whl.metadata (9.7 kB)
# Collecting termcolor<4.0.0,>=2.4.0 (from lerobot==0.4.1)
#   Downloading termcolor-3.2.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting mergedeep~=1.3 (from draccus==0.10.0->lerobot==0.4.1)
#   Downloading mergedeep-1.3.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting pyyaml~=6.0 (from draccus==0.10.0->lerobot==0.4.1)
#   Downloading pyyaml-6.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Collecting pyyaml-include~=1.4 (from draccus==0.10.0->lerobot==0.4.1)
#   Downloading pyyaml_include-1.4.1-py3-none-any.whl.metadata (1.3 kB)
# Collecting toml~=0.10 (from draccus==0.10.0->lerobot==0.4.1)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-inspect~=0.9.0 (from draccus==0.10.0->lerobot==0.4.1)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting numpy>=1.17 (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.1)
#   Downloading numpy-2.3.4-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting psutil (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.1)
#   Downloading psutil-7.1.3-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl.metadata (23 kB)
# Collecting safetensors>=0.4.3 (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.1)
#   Downloading safetensors-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting filelock (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting pyarrow>=21.0.0 (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading pyarrow-22.0.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.2 kB)
# Collecting dill<0.4.1,>=0.3.0 (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting pandas (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading pandas-2.3.3-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (4.67.1)
# Collecting xxhash (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading xxhash-3.6.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.17 (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.9.0,>=2023.1.0 (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting orderly-set<6,>=5.4.1 (from deepdiff<9.0.0,>=7.0.1->lerobot==0.4.1)
#   Downloading orderly_set-5.5.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting importlib_metadata (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.1)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting regex!=2019.12.17 (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.1)
#   Downloading regex-2025.11.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Collecting Pillow (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.1)
#   Downloading pillow-12.0.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting cloudpickle>=1.2.0 (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.1)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-extensions>=4.3.0 (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.1)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting farama-notifications>=0.0.1 (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.1)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub<0.36.0,>=0.34.2->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1)
#   Downloading hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting InquirerPy==0.3.4 (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1)
#   Downloading InquirerPy-0.3.4-py3-none-any.whl.metadata (8.1 kB)
# Collecting hf-transfer>=0.1.4 (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1)
#   Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting pfzy<0.4.0,>=0.3.1 (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1)
#   Downloading pfzy-0.3.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting prompt-toolkit<4.0.0,>=3.0.1 (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1)
#   Downloading prompt_toolkit-3.0.52-py3-none-any.whl.metadata (6.4 kB)
# Collecting imageio-ffmpeg (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.4.1)
#   Downloading imageio_ffmpeg-0.6.0-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting attrs>=19.2.0 (from jsonlines<5.0.0,>=4.0.0->lerobot==0.4.1)
#   Downloading attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting numpy>=1.17 (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.1)
#   Downloading numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting six (from pynput<1.9.0,>=1.7.7->lerobot==0.4.1)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting evdev>=1.3 (from pynput<1.9.0,>=1.7.7->lerobot==0.4.1)
#   Downloading evdev-1.9.2.tar.gz (33 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting python-xlib>=0.17 (from pynput<1.9.0,>=1.7.7->lerobot==0.4.1)
#   Downloading python_xlib-0.33-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting sympy>=1.13.3 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.1 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Collecting click>=8.0.1 (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1)
#   Downloading click-8.3.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1)
#   Downloading gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (4.3.6)
# Collecting protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1)
#   Downloading protobuf-6.33.0-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting pydantic<3 (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1)
#   Downloading pydantic-2.12.4-py3-none-any.whl.metadata (89 kB)
# Collecting sentry-sdk>=2.0.0 (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1)
#   Downloading sentry_sdk-2.44.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading aiohttp-3.13.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb<0.22.0,>=0.20.0->lerobot==0.4.1)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.1)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.1)
#   Downloading pydantic_core-2.41.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.1)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2025.10.5)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect~=0.9.0->draccus==0.10.0->lerobot==0.4.1)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting zipp>=3.20 (from importlib_metadata->diffusers<0.36.0,>=0.27.2->lerobot==0.4.1)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading markupsafe-3.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Collecting python-dateutil>=2.8.2 (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading frozenlist-1.8.0-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading multidict-6.7.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading propcache-0.4.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading yarl-1.22.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (75 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb<0.22.0,>=0.20.0->lerobot==0.4.1)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting wcwidth (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1)
#   Downloading wcwidth-0.2.14-py2.py3-none-any.whl.metadata (15 kB)
# Downloading draccus-0.10.0-py3-none-any.whl (71 kB)
# Downloading accelerate-1.11.0-py3-none-any.whl (375 kB)
# Downloading av-15.1.0-cp311-cp311-manylinux_2_28_x86_64.whl (39.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.6/39.6 MB 51.8 MB/s eta 0:00:00
# Downloading cmake-4.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (29.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.7/29.7 MB 169.2 MB/s eta 0:00:00
# Downloading datasets-4.1.1-py3-none-any.whl (503 kB)
# Downloading deepdiff-8.6.1-py3-none-any.whl (91 kB)
# Downloading diffusers-0.35.2-py3-none-any.whl (4.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 131.4 MB/s eta 0:00:00
# Downloading einops-0.8.1-py3-none-any.whl (64 kB)
# Downloading gymnasium-1.2.2-py3-none-any.whl (952 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.1/952.1 kB 59.3 MB/s eta 0:00:00
# Downloading huggingface_hub-0.35.3-py3-none-any.whl (564 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.3/564.3 kB 31.3 MB/s eta 0:00:00
# Downloading InquirerPy-0.3.4-py3-none-any.whl (67 kB)
# Downloading imageio-2.37.2-py3-none-any.whl (317 kB)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading opencv_python_headless-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (54.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 MB 170.8 MB/s eta 0:00:00
# Downloading pynput-1.8.1-py2.py3-none-any.whl (91 kB)
# Downloading pyserial-3.5-py2.py3-none-any.whl (90 kB)
# Downloading rerun_sdk-0.26.2-cp39-abi3-manylinux_2_28_x86_64.whl (98.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.8/98.8 MB 34.4 MB/s eta 0:00:00
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Downloading termcolor-3.2.0-py3-none-any.whl (7.7 kB)
# Downloading torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl (821.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.2/821.2 MB 26.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 81.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 139.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 99.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 49.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 55.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 117.3 MB/s eta 0:00:00
# Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 57.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 26.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 115.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 128.1 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 99.7 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 134.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 150.8 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.7/155.7 MB 109.4 MB/s eta 0:00:00
# Downloading torchcodec-0.5-cp311-cp311-manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 68.5 MB/s eta 0:00:00
# Downloading torchvision-0.22.1-cp311-cp311-manylinux_2_28_x86_64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 136.7 MB/s eta 0:00:00
# Downloading wandb-0.21.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.6/19.6 MB 107.0 MB/s eta 0:00:00
# Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading click-8.3.0-py3-none-any.whl (107 kB)
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
# Downloading gitpython-3.1.45-py3-none-any.whl (208 kB)
# Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 90.5 MB/s eta 0:00:00
# Downloading hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 118.6 MB/s eta 0:00:00
# Downloading mergedeep-1.3.4-py3-none-any.whl (6.4 kB)
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
# Downloading numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 161.2 MB/s eta 0:00:00
# Downloading orderly_set-5.5.0-py3-none-any.whl (13 kB)
# Downloading pillow-12.0.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 141.9 MB/s eta 0:00:00
# Downloading protobuf-6.33.0-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
# Downloading pyarrow-22.0.0-cp311-cp311-manylinux_2_28_x86_64.whl (47.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 148.1 MB/s eta 0:00:00
# Downloading pydantic-2.12.4-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 93.9 MB/s eta 0:00:00
# Downloading python_xlib-0.33-py2.py3-none-any.whl (182 kB)
# Downloading pyyaml-6.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (806 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.6/806.6 kB 49.6 MB/s eta 0:00:00
# Downloading pyyaml_include-1.4.1-py3-none-any.whl (19 kB)
# Downloading regex-2025.11.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (800 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.4/800.4 kB 41.9 MB/s eta 0:00:00
# Downloading safetensors-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (485 kB)
# Downloading sentry_sdk-2.44.0-py2.py3-none-any.whl (402 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 150.0 MB/s eta 0:00:00
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading filelock-3.20.0-py3-none-any.whl (16 kB)
# Downloading imageio_ffmpeg-0.6.0-py3-none-manylinux2014_x86_64.whl (29.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.5/29.5 MB 105.6 MB/s eta 0:00:00
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 93.6 MB/s eta 0:00:00
# Downloading pandas-2.3.3-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 24.8 MB/s eta 0:00:00
# Downloading psutil-7.1.3-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl (263 kB)
# Downloading xxhash-3.6.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
# Downloading aiohttp-3.13.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 75.8 MB/s eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading markupsafe-3.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (22 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 26.6 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading pfzy-0.3.4-py3-none-any.whl (8.5 kB)
# Downloading prompt_toolkit-3.0.52-py3-none-any.whl (391 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.8.0-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (231 kB)
# Downloading multidict-6.7.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (246 kB)
# Downloading propcache-0.4.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (210 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading yarl-1.22.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (365 kB)
# Downloading wcwidth-0.2.14-py2.py3-none-any.whl (37 kB)
# Building wheels for collected packages: lerobot, evdev
#   Building editable for lerobot (pyproject.toml) ... done
#   Created wheel for lerobot: filename=lerobot-0.4.1-0.editable-py3-none-any.whl size=15629 sha256=44986cbaa4ba40569934c993b553c14cf5f8a93d1db03f33cba4029096997a4b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ptyqlipl/wheels/15/0d/02/b9c6ff1c78574dee99101ad231194b3425eb4cd784ce8c8338
#   Building wheel for evdev (pyproject.toml) ... done
#   Created wheel for evdev: filename=evdev-1.9.2-cp311-cp311-linux_x86_64.whl size=74951 sha256=9c6ae76667a5dc9f2316a13534c4b4d61b6533f02953cd5982ae9435988e3e17
#   Stored in directory: /root/.cache/pip/wheels/72/97/d0/ea1b02915719d1cdb6a8810aa7683524c7aceedc5812cdeed7
# Successfully built lerobot evdev
# Installing collected packages: pytz, pyserial, nvidia-cusparselt-cu12, mpmath, farama-notifications, zipp, xxhash, wcwidth, tzdata, typing-extensions, torchcodec, toml, termcolor, sympy, smmap, six, setuptools, sentry-sdk, safetensors, regex, pyyaml, pyarrow, psutil, protobuf, propcache, Pillow, pfzy, orderly-set, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, mypy-extensions, multidict, mergedeep, MarkupSafe, imageio-ffmpeg, hf-xet, hf-transfer, fsspec, frozenlist, filelock, evdev, einops, dill, cmake, cloudpickle, click, av, attrs, annotated-types, aiohappyeyeballs, yarl, typing-inspection, typing-inspect, triton, rerun-sdk, pyyaml-include, python-xlib, python-dateutil, pydantic-core, prompt-toolkit, opencv-python-headless, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, multiprocess, jsonlines, jinja2, importlib_metadata, imageio, huggingface-hub, gymnasium, gitdb, deepdiff, aiosignal, pynput, pydantic, pandas, nvidia-cusolver-cu12, InquirerPy, gitpython, draccus, diffusers, aiohttp, wandb, torch, torchvision, datasets, accelerate, lerobot
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 65.6.3
#     Uninstalling setuptools-65.6.3:
#       Successfully uninstalled setuptools-65.6.3
# Successfully installed InquirerPy-0.3.4 MarkupSafe-3.0.3 Pillow-12.0.0 accelerate-1.11.0 aiohappyeyeballs-2.6.1 aiohttp-3.13.2 aiosignal-1.4.0 annotated-types-0.7.0 attrs-25.4.0 av-15.1.0 click-8.3.0 cloudpickle-3.1.2 cmake-4.1.2 datasets-4.1.1 deepdiff-8.6.1 diffusers-0.35.2 dill-0.4.0 draccus-0.10.0 einops-0.8.1 evdev-1.9.2 farama-notifications-0.0.4 filelock-3.20.0 frozenlist-1.8.0 fsspec-2025.9.0 gitdb-4.0.12 gitpython-3.1.45 gymnasium-1.2.2 hf-transfer-0.1.9 hf-xet-1.2.0 huggingface-hub-0.35.3 imageio-2.37.2 imageio-ffmpeg-0.6.0 importlib_metadata-8.7.0 jinja2-3.1.6 jsonlines-4.0.0 lerobot-0.4.1 mergedeep-1.3.4 mpmath-1.3.0 multidict-6.7.0 multiprocess-0.70.16 mypy-extensions-1.1.0 networkx-3.5 numpy-2.2.6 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 opencv-python-headless-4.12.0.88 orderly-set-5.5.0 pandas-2.3.3 pfzy-0.3.4 prompt-toolkit-3.0.52 propcache-0.4.1 protobuf-6.33.0 psutil-7.1.3 pyarrow-22.0.0 pydantic-2.12.4 pydantic-core-2.41.5 pynput-1.8.1 pyserial-3.5 python-dateutil-2.9.0.post0 python-xlib-0.33 pytz-2025.2 pyyaml-6.0.3 pyyaml-include-1.4.1 regex-2025.11.3 rerun-sdk-0.26.2 safetensors-0.6.2 sentry-sdk-2.44.0 setuptools-80.9.0 six-1.17.0 smmap-5.0.2 sympy-1.14.0 termcolor-3.2.0 toml-0.10.2 torch-2.7.1 torchcodec-0.5 torchvision-0.22.1 triton-3.3.1 typing-extensions-4.15.0 typing-inspect-0.9.0 typing-inspection-0.4.2 tzdata-2025.2 wandb-0.21.4 wcwidth-0.2.14 xxhash-3.6.0 yarl-1.22.0 zipp-3.23.0

# %% [markdown]
# ## Weights & Biases login
# This cell logs you into Weights & Biases (wandb) to enable experiment tracking and logging.

# %%
# !wandb login
# Out:
# /usr/local/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: berobemin to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %% [markdown]
# ## Start training ACT with LeRobot
#
# This cell runs the `train.py` script from the `lerobot` library to train a robot control policy.
#
# Make sure to adjust the following arguments to your setup:
#
# 1. `--dataset.repo_id=YOUR_HF_USERNAME/YOUR_DATASET`:
#    Replace this with the Hugging Face Hub repo ID where your dataset is stored, e.g., `pepijn223/il_gym0`.
#
# 2. `--policy.type=act`:
#    Specifies the policy configuration to use. `act` refers to [configuration_act.py](../lerobot/common/policies/act/configuration_act.py), which will automatically adapt to your dataset’s setup (e.g., number of motors and cameras).
#
# 3. `--output_dir=outputs/train/...`:
#    Directory where training logs and model checkpoints will be saved.
#
# 4. `--job_name=...`:
#    A name for this training job, used for logging and Weights & Biases.
#
# 5. `--policy.device=cuda`:
#    Use `cuda` if training on an NVIDIA GPU. Use `mps` for Apple Silicon, or `cpu` if no GPU is available.
#
# 6. `--wandb.enable=true`:
#    Enables Weights & Biases for visualizing training progress. You must be logged in via `wandb login` before running this.

# %%
# !rm -rf /content/lerobot/outputs/train/*

# %%
# !cd lerobot && python src/lerobot/scripts/lerobot_train.py \
  --dataset.repo_id=berobemin/record-test2 \
  --policy.push_to_hub=False \
  --policy.type=act \
  --output_dir=outputs/train/act_record_test2 \
  --job_name=act_record_test \
  --policy.device=cuda \
  --wandb.enable=true
# Out:
# INFO 2025-11-12 03:58:01 ot_train.py:163 {'batch_size': 8,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
#                                           'hue': {'kwargs': {'hue': [-0.05,
#                                                                      0.05]},
#                                                   'type': 'ColorJitter',
#                                                   'weight': 1.0},
#                                           'saturation': {'kwargs': {'saturation': [0.5,
#                                                                                    1.5]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'sharpness': {'kwargs': {'sharpness': [0.5,
#                                                                                  1.5]},
#                                                         'type': 'SharpnessJitter',
#                                                         'weight': 1.0}}},
#              'repo_id': 'berobemin/record-test2',
#              'revision': None,
#              'root': None,
#              'streaming': False,
#              'use_imagenet_stats': True,
#              'video_backend': 'torchcodec'},
#  'env': None,
#  'eval': {'batch_size': 50, 'n_episodes': 50, 'use_async_envs': False},
#  'eval_freq': 20000,
#  'job_name': 'act_record_test',
#  'log_freq': 200,
#  'num_workers': 4,
#  'optimizer': {'betas': [0.9, 0.999],
#                'eps': 1e-08,
#                'grad_clip_norm': 10.0,
#                'lr': 1e-05,
#                'type': 'adamw',
#                'weight_decay': 0.0001},
#  'output_dir': 'outputs/train/act_record_test2',
#  'policy': {'chunk_size': 100,
#             'device': 'cuda',
#             'dim_feedforward': 3200,
#             'dim_model': 512,
#             'dropout': 0.1,
#             'feedforward_activation': 'relu',
#             'input_features': {},
#             'kl_weight': 10.0,
#             'latent_dim': 32,
#             'license': None,
#             'n_action_steps': 100,
#             'n_decoder_layers': 1,
#             'n_encoder_layers': 4,
#             'n_heads': 8,
#             'n_obs_steps': 1,
#             'n_vae_encoder_layers': 4,
#             'normalization_mapping': {'ACTION': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'STATE': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'VISUAL': <NormalizationMode.MEAN_STD: 'MEAN_STD'>},
#             'optimizer_lr': 1e-05,
#             'optimizer_lr_backbone': 1e-05,
#             'optimizer_weight_decay': 0.0001,
#             'output_features': {},
#             'pre_norm': False,
#             'pretrained_backbone_weights': 'ResNet18_Weights.IMAGENET1K_V1',
#             'pretrained_path': None,
#             'private': None,
#             'push_to_hub': False,
#             'replace_final_stride_with_dilation': False,
#             'repo_id': None,
#             'tags': None,
#             'temporal_ensemble_coeff': None,
#             'type': 'act',
#             'use_amp': False,
#             'use_vae': True,
#             'vision_backbone': 'resnet18'},
#  'rename_map': {},
#  'resume': False,
#  'save_checkpoint': True,
#  'save_freq': 20000,
#  'scheduler': None,
#  'seed': 1000,
#  'steps': 100000,
#  'use_policy_training_preset': True,
#  'wandb': {'disable_artifact': False,
#            'enable': True,
#            'entity': None,
#            'mode': None,
#            'notes': None,
#            'project': 'lerobot',
#            'run_id': None}}
# /usr/local/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# INFO 2025-11-12 03:58:03 db_utils.py:102 Logs will be synced with wandb.
# INFO 2025-11-12 03:58:03 db_utils.py:103 Track this run --> https://wandb.ai/berobemin/lerobot/runs/cnyk5btq
# INFO 2025-11-12 03:58:03 ot_train.py:183 Creating dataset
# Fetching 4 files:   0% 0/4 [00:00<?, ?it/s]
# meta/episodes/chunk-000/file-000.parquet:   0% 0.00/48.9k [00:00<?, ?B/s]
#
# meta/tasks.parquet:   0% 0.00/2.15k [00:00<?, ?B/s]
#
#
# info.json: 2.60kB [00:00, 4.66MB/s]
#
#
#
# stats.json: 9.93kB [00:00, 20.3MB/s]
#
#
# meta/tasks.parquet: 100% 2.15k/2.15k [00:00<00:00, 2.39kB/s]
#
# meta/episodes/chunk-000/file-000.parquet: 100% 48.9k/48.9k [00:01<00:00, 43.7kB/s]
# Fetching 4 files: 100% 4/4 [00:01<00:00,  2.95it/s]
# Fetching 8 files:   0% 0/8 [00:00<?, ?it/s]
# videos/observation.images.front_close/ch(…):   0% 0.00/64.5M [00:00<?, ?B/s]
#
# data/chunk-000/file-000.parquet:   0% 0.00/179k [00:00<?, ?B/s]
#
#
# README.md: 3.09kB [00:00, 4.74MB/s]
#
#
#
# .gitattributes: 2.46kB [00:00, 6.23MB/s]
# Fetching 8 files:  12% 1/8 [00:00<00:02,  2.62it/s]
#
# data/chunk-000/file-000.parquet: 100% 179k/179k [00:00<00:00, 760kB/s]
#
# videos/observation.images.front_close/ch(…): 100% 64.5M/64.5M [00:02<00:00, 24.7MB/s]
# Fetching 8 files: 100% 8/8 [00:02<00:00,  2.82it/s]
# INFO 2025-11-12 03:58:08 ot_train.py:202 Creating policy
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 221MB/s]
# INFO 2025-11-12 03:58:09 ot_train.py:247 Creating optimizer and scheduler
# INFO 2025-11-12 03:58:09 ot_train.py:259 Output dir: outputs/train/act_record_test2
# INFO 2025-11-12 03:58:09 ot_train.py:262 cfg.steps=100000 (100K)
# INFO 2025-11-12 03:58:09 ot_train.py:263 dataset.num_frames=4474 (4K)
# INFO 2025-11-12 03:58:09 ot_train.py:264 dataset.num_episodes=5
# INFO 2025-11-12 03:58:09 ot_train.py:267 Effective batch size: 8 x 1 = 8
# INFO 2025-11-12 03:58:09 ot_train.py:268 num_learnable_params=51597190 (52M)
# INFO 2025-11-12 03:58:09 ot_train.py:269 num_total_params=51597190 (52M)
# INFO 2025-11-12 03:58:09 ot_train.py:324 Start offline training on a fixed dataset
# INFO 2025-11-12 03:58:22 ot_train.py:351 step:200 smpl:2K ep:2 epch:0.36 loss:7.017 grdn:159.046 lr:1.0e-05 updt_s:0.056 data_s:0.006
# INFO 2025-11-12 03:58:33 ot_train.py:351 step:400 smpl:3K ep:4 epch:0.72 loss:2.932 grdn:88.183 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 03:58:45 ot_train.py:351 step:600 smpl:5K ep:5 epch:1.07 loss:2.430 grdn:76.760 lr:1.0e-05 updt_s:0.053 data_s:0.006
# INFO 2025-11-12 03:58:56 ot_train.py:351 step:800 smpl:6K ep:7 epch:1.43 loss:2.141 grdn:68.031 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 03:59:07 ot_train.py:351 step:1K smpl:8K ep:9 epch:1.79 loss:1.925 grdn:64.277 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 03:59:19 ot_train.py:351 step:1K smpl:10K ep:11 epch:2.15 loss:1.785 grdn:61.721 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 03:59:30 ot_train.py:351 step:1K smpl:11K ep:13 epch:2.50 loss:1.586 grdn:57.596 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 03:59:41 ot_train.py:351 step:2K smpl:13K ep:14 epch:2.86 loss:1.439 grdn:55.372 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 03:59:53 ot_train.py:351 step:2K smpl:14K ep:16 epch:3.22 loss:1.294 grdn:53.477 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:00:04 ot_train.py:351 step:2K smpl:16K ep:18 epch:3.58 loss:1.180 grdn:50.614 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:00:15 ot_train.py:351 step:2K smpl:18K ep:20 epch:3.93 loss:1.070 grdn:48.192 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:00:27 ot_train.py:351 step:2K smpl:19K ep:21 epch:4.29 loss:0.957 grdn:45.177 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 04:00:38 ot_train.py:351 step:3K smpl:21K ep:23 epch:4.65 loss:0.864 grdn:42.884 lr:1.0e-05 updt_s:0.054 data_s:0.003
# INFO 2025-11-12 04:00:49 ot_train.py:351 step:3K smpl:22K ep:25 epch:5.01 loss:0.779 grdn:40.358 lr:1.0e-05 updt_s:0.051 data_s:0.004
# INFO 2025-11-12 04:01:01 ot_train.py:351 step:3K smpl:24K ep:27 epch:5.36 loss:0.713 grdn:39.327 lr:1.0e-05 updt_s:0.053 data_s:0.005
# INFO 2025-11-12 04:01:12 ot_train.py:351 step:3K smpl:26K ep:29 epch:5.72 loss:0.638 grdn:36.045 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:01:24 ot_train.py:351 step:3K smpl:27K ep:30 epch:6.08 loss:0.585 grdn:35.106 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 04:01:35 ot_train.py:351 step:4K smpl:29K ep:32 epch:6.44 loss:0.538 grdn:33.389 lr:1.0e-05 updt_s:0.054 data_s:0.003
# INFO 2025-11-12 04:01:46 ot_train.py:351 step:4K smpl:30K ep:34 epch:6.79 loss:0.484 grdn:31.298 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:01:58 ot_train.py:351 step:4K smpl:32K ep:36 epch:7.15 loss:0.442 grdn:29.794 lr:1.0e-05 updt_s:0.053 data_s:0.006
# INFO 2025-11-12 04:02:09 ot_train.py:351 step:4K smpl:34K ep:38 epch:7.51 loss:0.413 grdn:28.698 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:02:21 ot_train.py:351 step:4K smpl:35K ep:39 epch:7.87 loss:0.384 grdn:27.890 lr:1.0e-05 updt_s:0.054 data_s:0.003
# INFO 2025-11-12 04:02:33 ot_train.py:351 step:5K smpl:37K ep:41 epch:8.23 loss:0.351 grdn:26.136 lr:1.0e-05 updt_s:0.053 data_s:0.006
# INFO 2025-11-12 04:02:44 ot_train.py:351 step:5K smpl:38K ep:43 epch:8.58 loss:0.333 grdn:25.384 lr:1.0e-05 updt_s:0.054 data_s:0.003
# INFO 2025-11-12 04:02:55 ot_train.py:351 step:5K smpl:40K ep:45 epch:8.94 loss:0.312 grdn:24.485 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:03:07 ot_train.py:351 step:5K smpl:42K ep:46 epch:9.30 loss:0.289 grdn:23.672 lr:1.0e-05 updt_s:0.053 data_s:0.006
# INFO 2025-11-12 04:03:19 ot_train.py:351 step:5K smpl:43K ep:48 epch:9.66 loss:0.275 grdn:22.657 lr:1.0e-05 updt_s:0.054 data_s:0.003
# INFO 2025-11-12 04:03:30 ot_train.py:351 step:6K smpl:45K ep:50 epch:10.01 loss:0.266 grdn:22.173 lr:1.0e-05 updt_s:0.052 data_s:0.004
# INFO 2025-11-12 04:03:42 ot_train.py:351 step:6K smpl:46K ep:52 epch:10.37 loss:0.250 grdn:21.155 lr:1.0e-05 updt_s:0.053 data_s:0.005
# INFO 2025-11-12 04:03:53 ot_train.py:351 step:6K smpl:48K ep:54 epch:10.73 loss:0.236 grdn:20.513 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:04:04 ot_train.py:351 step:6K smpl:50K ep:55 epch:11.09 loss:0.230 grdn:20.032 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:04:16 ot_train.py:351 step:6K smpl:51K ep:57 epch:11.44 loss:0.218 grdn:19.761 lr:1.0e-05 updt_s:0.055 data_s:0.003
# INFO 2025-11-12 04:04:27 ot_train.py:351 step:7K smpl:53K ep:59 epch:11.80 loss:0.212 grdn:19.211 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:04:39 ot_train.py:351 step:7K smpl:54K ep:61 epch:12.16 loss:0.208 grdn:19.216 lr:1.0e-05 updt_s:0.053 data_s:0.006
# INFO 2025-11-12 04:04:51 ot_train.py:351 step:7K smpl:56K ep:63 epch:12.52 loss:0.196 grdn:18.265 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:05:02 ot_train.py:351 step:7K smpl:58K ep:64 epch:12.87 loss:0.190 grdn:18.049 lr:1.0e-05 updt_s:0.054 data_s:0.003
# INFO 2025-11-12 04:05:13 ot_train.py:351 step:7K smpl:59K ep:66 epch:13.23 loss:0.187 grdn:17.987 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 04:05:25 ot_train.py:351 step:8K smpl:61K ep:68 epch:13.59 loss:0.179 grdn:17.567 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:05:36 ot_train.py:351 step:8K smpl:62K ep:70 epch:13.95 loss:0.173 grdn:16.765 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:05:48 ot_train.py:351 step:8K smpl:64K ep:72 epch:14.30 loss:0.168 grdn:16.629 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:05:59 ot_train.py:351 step:8K smpl:66K ep:73 epch:14.66 loss:0.165 grdn:16.612 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:06:10 ot_train.py:351 step:8K smpl:67K ep:75 epch:15.02 loss:0.161 grdn:16.210 lr:1.0e-05 updt_s:0.052 data_s:0.004
# INFO 2025-11-12 04:06:21 ot_train.py:351 step:9K smpl:69K ep:77 epch:15.38 loss:0.158 grdn:15.878 lr:1.0e-05 updt_s:0.050 data_s:0.006
# INFO 2025-11-12 04:06:33 ot_train.py:351 step:9K smpl:70K ep:79 epch:15.74 loss:0.151 grdn:15.464 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:06:45 ot_train.py:351 step:9K smpl:72K ep:80 epch:16.09 loss:0.150 grdn:15.530 lr:1.0e-05 updt_s:0.054 data_s:0.006
# INFO 2025-11-12 04:06:56 ot_train.py:351 step:9K smpl:74K ep:82 epch:16.45 loss:0.144 grdn:14.720 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:07:07 ot_train.py:351 step:9K smpl:75K ep:84 epch:16.81 loss:0.146 grdn:15.256 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:07:18 ot_train.py:351 step:10K smpl:77K ep:86 epch:17.17 loss:0.142 grdn:14.730 lr:1.0e-05 updt_s:0.050 data_s:0.006
# INFO 2025-11-12 04:07:29 ot_train.py:351 step:10K smpl:78K ep:88 epch:17.52 loss:0.137 grdn:14.410 lr:1.0e-05 updt_s:0.050 data_s:0.003
# INFO 2025-11-12 04:07:40 ot_train.py:351 step:10K smpl:80K ep:89 epch:17.88 loss:0.134 grdn:13.879 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:07:51 ot_train.py:351 step:10K smpl:82K ep:91 epch:18.24 loss:0.137 grdn:14.205 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 04:08:03 ot_train.py:351 step:10K smpl:83K ep:93 epch:18.60 loss:0.128 grdn:13.449 lr:1.0e-05 updt_s:0.054 data_s:0.003
# INFO 2025-11-12 04:08:14 ot_train.py:351 step:11K smpl:85K ep:95 epch:18.95 loss:0.127 grdn:13.452 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:08:25 ot_train.py:351 step:11K smpl:86K ep:97 epch:19.31 loss:0.127 grdn:13.608 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 04:08:37 ot_train.py:351 step:11K smpl:88K ep:98 epch:19.67 loss:0.124 grdn:13.257 lr:1.0e-05 updt_s:0.054 data_s:0.003
# INFO 2025-11-12 04:08:48 ot_train.py:351 step:11K smpl:90K ep:100 epch:20.03 loss:0.122 grdn:13.333 lr:1.0e-05 updt_s:0.052 data_s:0.004
# INFO 2025-11-12 04:09:00 ot_train.py:351 step:11K smpl:91K ep:102 epch:20.38 loss:0.119 grdn:12.908 lr:1.0e-05 updt_s:0.052 data_s:0.005
# INFO 2025-11-12 04:09:11 ot_train.py:351 step:12K smpl:93K ep:104 epch:20.74 loss:0.120 grdn:12.931 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:09:23 ot_train.py:351 step:12K smpl:94K ep:105 epch:21.10 loss:0.117 grdn:12.485 lr:1.0e-05 updt_s:0.053 data_s:0.006
# INFO 2025-11-12 04:09:34 ot_train.py:351 step:12K smpl:96K ep:107 epch:21.46 loss:0.114 grdn:12.704 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:09:46 ot_train.py:351 step:12K smpl:98K ep:109 epch:21.81 loss:0.113 grdn:12.537 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:09:57 ot_train.py:351 step:12K smpl:99K ep:111 epch:22.17 loss:0.116 grdn:12.432 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 04:10:09 ot_train.py:351 step:13K smpl:101K ep:113 epch:22.53 loss:0.110 grdn:12.072 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:10:19 ot_train.py:351 step:13K smpl:102K ep:114 epch:22.89 loss:0.109 grdn:12.298 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:10:32 ot_train.py:351 step:13K smpl:104K ep:116 epch:23.25 loss:0.104 grdn:11.538 lr:1.0e-05 updt_s:0.054 data_s:0.006
# INFO 2025-11-12 04:10:43 ot_train.py:351 step:13K smpl:106K ep:118 epch:23.60 loss:0.104 grdn:11.659 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:10:54 ot_train.py:351 step:13K smpl:107K ep:120 epch:23.96 loss:0.106 grdn:11.709 lr:1.0e-05 updt_s:0.050 data_s:0.003
# INFO 2025-11-12 04:11:05 ot_train.py:351 step:14K smpl:109K ep:122 epch:24.32 loss:0.102 grdn:11.517 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:11:17 ot_train.py:351 step:14K smpl:110K ep:123 epch:24.68 loss:0.107 grdn:11.137 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:11:28 ot_train.py:351 step:14K smpl:112K ep:125 epch:25.03 loss:0.099 grdn:11.213 lr:1.0e-05 updt_s:0.051 data_s:0.004
# INFO 2025-11-12 04:11:39 ot_train.py:351 step:14K smpl:114K ep:127 epch:25.39 loss:0.097 grdn:11.247 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 04:11:50 ot_train.py:351 step:14K smpl:115K ep:129 epch:25.75 loss:0.098 grdn:10.642 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:12:03 ot_train.py:351 step:15K smpl:117K ep:131 epch:26.11 loss:0.095 grdn:10.936 lr:1.0e-05 updt_s:0.055 data_s:0.006
# INFO 2025-11-12 04:12:15 ot_train.py:351 step:15K smpl:118K ep:132 epch:26.46 loss:0.097 grdn:10.724 lr:1.0e-05 updt_s:0.055 data_s:0.003
# INFO 2025-11-12 04:12:26 ot_train.py:351 step:15K smpl:120K ep:134 epch:26.82 loss:0.097 grdn:10.681 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:12:38 ot_train.py:351 step:15K smpl:122K ep:136 epch:27.18 loss:0.095 grdn:10.818 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:12:49 ot_train.py:351 step:15K smpl:123K ep:138 epch:27.54 loss:0.092 grdn:10.374 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:13:01 ot_train.py:351 step:16K smpl:125K ep:139 epch:27.89 loss:0.092 grdn:10.252 lr:1.0e-05 updt_s:0.056 data_s:0.003
# INFO 2025-11-12 04:13:12 ot_train.py:351 step:16K smpl:126K ep:141 epch:28.25 loss:0.093 grdn:10.329 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:13:24 ot_train.py:351 step:16K smpl:128K ep:143 epch:28.61 loss:0.091 grdn:10.065 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:13:35 ot_train.py:351 step:16K smpl:130K ep:145 epch:28.97 loss:0.086 grdn:9.755 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:13:46 ot_train.py:351 step:16K smpl:131K ep:147 epch:29.32 loss:0.090 grdn:10.227 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:13:58 ot_train.py:351 step:17K smpl:133K ep:148 epch:29.68 loss:0.086 grdn:9.759 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:14:09 ot_train.py:351 step:17K smpl:134K ep:150 epch:30.04 loss:0.087 grdn:9.875 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:14:20 ot_train.py:351 step:17K smpl:136K ep:152 epch:30.40 loss:0.084 grdn:9.836 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:14:32 ot_train.py:351 step:17K smpl:138K ep:154 epch:30.76 loss:0.084 grdn:9.313 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:14:44 ot_train.py:351 step:17K smpl:139K ep:156 epch:31.11 loss:0.081 grdn:9.505 lr:1.0e-05 updt_s:0.054 data_s:0.006
# INFO 2025-11-12 04:14:55 ot_train.py:351 step:18K smpl:141K ep:157 epch:31.47 loss:0.082 grdn:9.465 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:15:06 ot_train.py:351 step:18K smpl:142K ep:159 epch:31.83 loss:0.082 grdn:9.241 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:15:18 ot_train.py:351 step:18K smpl:144K ep:161 epch:32.19 loss:0.081 grdn:9.232 lr:1.0e-05 updt_s:0.055 data_s:0.006
# INFO 2025-11-12 04:15:30 ot_train.py:351 step:18K smpl:146K ep:163 epch:32.54 loss:0.080 grdn:9.276 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:15:41 ot_train.py:351 step:18K smpl:147K ep:165 epch:32.90 loss:0.080 grdn:9.191 lr:1.0e-05 updt_s:0.050 data_s:0.003
# INFO 2025-11-12 04:15:53 ot_train.py:351 step:19K smpl:149K ep:166 epch:33.26 loss:0.078 grdn:9.117 lr:1.0e-05 updt_s:0.055 data_s:0.007
# INFO 2025-11-12 04:16:05 ot_train.py:351 step:19K smpl:150K ep:168 epch:33.62 loss:0.078 grdn:9.034 lr:1.0e-05 updt_s:0.054 data_s:0.003
# INFO 2025-11-12 04:16:16 ot_train.py:351 step:19K smpl:152K ep:170 epch:33.97 loss:0.076 grdn:8.732 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:16:27 ot_train.py:351 step:19K smpl:154K ep:172 epch:34.33 loss:0.076 grdn:8.917 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 04:16:39 ot_train.py:351 step:19K smpl:155K ep:173 epch:34.69 loss:0.077 grdn:8.502 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:16:51 ot_train.py:351 step:20K smpl:157K ep:175 epch:35.05 loss:0.075 grdn:8.703 lr:1.0e-05 updt_s:0.054 data_s:0.004
# INFO 2025-11-12 04:17:02 ot_train.py:351 step:20K smpl:158K ep:177 epch:35.40 loss:0.073 grdn:8.597 lr:1.0e-05 updt_s:0.053 data_s:0.005
# INFO 2025-11-12 04:17:14 ot_train.py:351 step:20K smpl:160K ep:179 epch:35.76 loss:0.075 grdn:8.575 lr:1.0e-05 updt_s:0.055 data_s:0.003
# INFO 2025-11-12 04:17:14 ot_train.py:361 Checkpoint policy after step 20000
# INFO 2025-11-12 04:17:28 ot_train.py:351 step:20K smpl:162K ep:181 epch:36.12 loss:0.074 grdn:8.499 lr:1.0e-05 updt_s:0.054 data_s:0.006
# INFO 2025-11-12 04:17:39 ot_train.py:351 step:20K smpl:163K ep:182 epch:36.48 loss:0.071 grdn:8.212 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:17:50 ot_train.py:351 step:21K smpl:165K ep:184 epch:36.84 loss:0.073 grdn:8.462 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:18:01 ot_train.py:351 step:21K smpl:166K ep:186 epch:37.19 loss:0.071 grdn:8.391 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:18:13 ot_train.py:351 step:21K smpl:168K ep:188 epch:37.55 loss:0.071 grdn:8.238 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:18:24 ot_train.py:351 step:21K smpl:170K ep:190 epch:37.91 loss:0.073 grdn:8.429 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:18:35 ot_train.py:351 step:21K smpl:171K ep:191 epch:38.27 loss:0.069 grdn:7.872 lr:1.0e-05 updt_s:0.053 data_s:0.006
# INFO 2025-11-12 04:18:47 ot_train.py:351 step:22K smpl:173K ep:193 epch:38.62 loss:0.068 grdn:7.827 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:18:58 ot_train.py:351 step:22K smpl:174K ep:195 epch:38.98 loss:0.070 grdn:7.925 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:19:10 ot_train.py:351 step:22K smpl:176K ep:197 epch:39.34 loss:0.067 grdn:7.792 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:19:21 ot_train.py:351 step:22K smpl:178K ep:198 epch:39.70 loss:0.067 grdn:7.968 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:19:32 ot_train.py:351 step:22K smpl:179K ep:200 epch:40.05 loss:0.067 grdn:7.870 lr:1.0e-05 updt_s:0.051 data_s:0.004
# INFO 2025-11-12 04:19:43 ot_train.py:351 step:23K smpl:181K ep:202 epch:40.41 loss:0.068 grdn:7.838 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 04:19:54 ot_train.py:351 step:23K smpl:182K ep:204 epch:40.77 loss:0.066 grdn:7.668 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:20:06 ot_train.py:351 step:23K smpl:184K ep:206 epch:41.13 loss:0.067 grdn:7.736 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:20:17 ot_train.py:351 step:23K smpl:186K ep:207 epch:41.48 loss:0.066 grdn:7.584 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:20:28 ot_train.py:351 step:23K smpl:187K ep:209 epch:41.84 loss:0.064 grdn:7.249 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:20:40 ot_train.py:351 step:24K smpl:189K ep:211 epch:42.20 loss:0.066 grdn:7.587 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 04:20:51 ot_train.py:351 step:24K smpl:190K ep:213 epch:42.56 loss:0.063 grdn:7.298 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:21:02 ot_train.py:351 step:24K smpl:192K ep:215 epch:42.91 loss:0.063 grdn:7.208 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:21:14 ot_train.py:351 step:24K smpl:194K ep:216 epch:43.27 loss:0.064 grdn:7.247 lr:1.0e-05 updt_s:0.054 data_s:0.006
# INFO 2025-11-12 04:21:25 ot_train.py:351 step:24K smpl:195K ep:218 epch:43.63 loss:0.065 grdn:7.586 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:21:36 ot_train.py:351 step:25K smpl:197K ep:220 epch:43.99 loss:0.065 grdn:7.236 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:21:48 ot_train.py:351 step:25K smpl:198K ep:222 epch:44.35 loss:0.062 grdn:7.224 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:21:59 ot_train.py:351 step:25K smpl:200K ep:224 epch:44.70 loss:0.063 grdn:7.302 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:22:10 ot_train.py:351 step:25K smpl:202K ep:225 epch:45.06 loss:0.063 grdn:7.026 lr:1.0e-05 updt_s:0.051 data_s:0.004
# INFO 2025-11-12 04:22:21 ot_train.py:351 step:25K smpl:203K ep:227 epch:45.42 loss:0.062 grdn:6.994 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:22:33 ot_train.py:351 step:26K smpl:205K ep:229 epch:45.78 loss:0.061 grdn:7.032 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:22:44 ot_train.py:351 step:26K smpl:206K ep:231 epch:46.13 loss:0.060 grdn:7.132 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:22:55 ot_train.py:351 step:26K smpl:208K ep:232 epch:46.49 loss:0.061 grdn:7.047 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:23:07 ot_train.py:351 step:26K smpl:210K ep:234 epch:46.85 loss:0.059 grdn:6.666 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:23:18 ot_train.py:351 step:26K smpl:211K ep:236 epch:47.21 loss:0.058 grdn:6.778 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 04:23:30 ot_train.py:351 step:27K smpl:213K ep:238 epch:47.56 loss:0.060 grdn:6.776 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:23:41 ot_train.py:351 step:27K smpl:214K ep:240 epch:47.92 loss:0.059 grdn:6.869 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:23:53 ot_train.py:351 step:27K smpl:216K ep:241 epch:48.28 loss:0.060 grdn:6.918 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:24:04 ot_train.py:351 step:27K smpl:218K ep:243 epch:48.64 loss:0.057 grdn:6.287 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:24:15 ot_train.py:351 step:27K smpl:219K ep:245 epch:48.99 loss:0.059 grdn:6.677 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:24:27 ot_train.py:351 step:28K smpl:221K ep:247 epch:49.35 loss:0.058 grdn:6.665 lr:1.0e-05 updt_s:0.054 data_s:0.006
# INFO 2025-11-12 04:24:38 ot_train.py:351 step:28K smpl:222K ep:249 epch:49.71 loss:0.058 grdn:6.618 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:24:50 ot_train.py:351 step:28K smpl:224K ep:250 epch:50.07 loss:0.056 grdn:6.469 lr:1.0e-05 updt_s:0.053 data_s:0.004
# INFO 2025-11-12 04:25:02 ot_train.py:351 step:28K smpl:226K ep:252 epch:50.42 loss:0.057 grdn:6.478 lr:1.0e-05 updt_s:0.054 data_s:0.006
# INFO 2025-11-12 04:25:13 ot_train.py:351 step:28K smpl:227K ep:254 epch:50.78 loss:0.057 grdn:6.580 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:25:24 ot_train.py:351 step:29K smpl:229K ep:256 epch:51.14 loss:0.056 grdn:6.375 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:25:35 ot_train.py:351 step:29K smpl:230K ep:257 epch:51.50 loss:0.056 grdn:6.458 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:25:46 ot_train.py:351 step:29K smpl:232K ep:259 epch:51.86 loss:0.055 grdn:6.199 lr:1.0e-05 updt_s:0.050 data_s:0.003
# INFO 2025-11-12 04:25:57 ot_train.py:351 step:29K smpl:234K ep:261 epch:52.21 loss:0.055 grdn:6.227 lr:1.0e-05 updt_s:0.050 data_s:0.006
# INFO 2025-11-12 04:26:09 ot_train.py:351 step:29K smpl:235K ep:263 epch:52.57 loss:0.055 grdn:6.039 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:26:20 ot_train.py:351 step:30K smpl:237K ep:265 epch:52.93 loss:0.055 grdn:6.246 lr:1.0e-05 updt_s:0.054 data_s:0.003
# INFO 2025-11-12 04:26:32 ot_train.py:351 step:30K smpl:238K ep:266 epch:53.29 loss:0.055 grdn:6.121 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:26:43 ot_train.py:351 step:30K smpl:240K ep:268 epch:53.64 loss:0.054 grdn:6.198 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:26:54 ot_train.py:351 step:30K smpl:242K ep:270 epch:54.00 loss:0.054 grdn:6.177 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:27:06 ot_train.py:351 step:30K smpl:243K ep:272 epch:54.36 loss:0.054 grdn:6.048 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:27:17 ot_train.py:351 step:31K smpl:245K ep:274 epch:54.72 loss:0.055 grdn:6.268 lr:1.0e-05 updt_s:0.056 data_s:0.003
# INFO 2025-11-12 04:27:29 ot_train.py:351 step:31K smpl:246K ep:275 epch:55.07 loss:0.057 grdn:6.183 lr:1.0e-05 updt_s:0.053 data_s:0.004
# INFO 2025-11-12 04:27:41 ot_train.py:351 step:31K smpl:248K ep:277 epch:55.43 loss:0.053 grdn:6.197 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:27:52 ot_train.py:351 step:31K smpl:250K ep:279 epch:55.79 loss:0.052 grdn:5.921 lr:1.0e-05 updt_s:0.054 data_s:0.003
# INFO 2025-11-12 04:28:04 ot_train.py:351 step:31K smpl:251K ep:281 epch:56.15 loss:0.053 grdn:5.944 lr:1.0e-05 updt_s:0.053 data_s:0.006
# INFO 2025-11-12 04:28:15 ot_train.py:351 step:32K smpl:253K ep:283 epch:56.50 loss:0.052 grdn:5.808 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:28:26 ot_train.py:351 step:32K smpl:254K ep:284 epch:56.86 loss:0.052 grdn:5.829 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:28:38 ot_train.py:351 step:32K smpl:256K ep:286 epch:57.22 loss:0.052 grdn:5.808 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:28:49 ot_train.py:351 step:32K smpl:258K ep:288 epch:57.58 loss:0.052 grdn:5.717 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:29:01 ot_train.py:351 step:32K smpl:259K ep:290 epch:57.93 loss:0.051 grdn:5.890 lr:1.0e-05 updt_s:0.054 data_s:0.003
# INFO 2025-11-12 04:29:13 ot_train.py:351 step:33K smpl:261K ep:291 epch:58.29 loss:0.051 grdn:5.623 lr:1.0e-05 updt_s:0.053 data_s:0.006
# INFO 2025-11-12 04:29:24 ot_train.py:351 step:33K smpl:262K ep:293 epch:58.65 loss:0.052 grdn:5.835 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:29:35 ot_train.py:351 step:33K smpl:264K ep:295 epch:59.01 loss:0.051 grdn:5.781 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:29:47 ot_train.py:351 step:33K smpl:266K ep:297 epch:59.37 loss:0.051 grdn:6.063 lr:1.0e-05 updt_s:0.053 data_s:0.006
# INFO 2025-11-12 04:29:58 ot_train.py:351 step:33K smpl:267K ep:299 epch:59.72 loss:0.051 grdn:5.922 lr:1.0e-05 updt_s:0.054 data_s:0.004
# INFO 2025-11-12 04:30:10 ot_train.py:351 step:34K smpl:269K ep:300 epch:60.08 loss:0.051 grdn:5.920 lr:1.0e-05 updt_s:0.052 data_s:0.004
# INFO 2025-11-12 04:30:22 ot_train.py:351 step:34K smpl:270K ep:302 epch:60.44 loss:0.050 grdn:5.715 lr:1.0e-05 updt_s:0.054 data_s:0.006
# INFO 2025-11-12 04:30:33 ot_train.py:351 step:34K smpl:272K ep:304 epch:60.80 loss:0.049 grdn:5.469 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:30:44 ot_train.py:351 step:34K smpl:274K ep:306 epch:61.15 loss:0.050 grdn:5.729 lr:1.0e-05 updt_s:0.053 data_s:0.006
# INFO 2025-11-12 04:30:56 ot_train.py:351 step:34K smpl:275K ep:308 epch:61.51 loss:0.049 grdn:5.495 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:31:07 ot_train.py:351 step:35K smpl:277K ep:309 epch:61.87 loss:0.051 grdn:5.542 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:31:18 ot_train.py:351 step:35K smpl:278K ep:311 epch:62.23 loss:0.049 grdn:5.555 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:31:29 ot_train.py:351 step:35K smpl:280K ep:313 epch:62.58 loss:0.048 grdn:5.529 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:31:40 ot_train.py:351 step:35K smpl:282K ep:315 epch:62.94 loss:0.050 grdn:5.726 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:31:52 ot_train.py:351 step:35K smpl:283K ep:316 epch:63.30 loss:0.049 grdn:5.493 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:32:03 ot_train.py:351 step:36K smpl:285K ep:318 epch:63.66 loss:0.048 grdn:5.382 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:32:14 ot_train.py:351 step:36K smpl:286K ep:320 epch:64.01 loss:0.049 grdn:5.560 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:32:26 ot_train.py:351 step:36K smpl:288K ep:322 epch:64.37 loss:0.049 grdn:5.450 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:32:37 ot_train.py:351 step:36K smpl:290K ep:324 epch:64.73 loss:0.048 grdn:5.447 lr:1.0e-05 updt_s:0.050 data_s:0.003
# INFO 2025-11-12 04:32:48 ot_train.py:351 step:36K smpl:291K ep:325 epch:65.09 loss:0.048 grdn:5.486 lr:1.0e-05 updt_s:0.051 data_s:0.004
# INFO 2025-11-12 04:33:00 ot_train.py:351 step:37K smpl:293K ep:327 epch:65.44 loss:0.048 grdn:5.365 lr:1.0e-05 updt_s:0.054 data_s:0.006
# INFO 2025-11-12 04:33:11 ot_train.py:351 step:37K smpl:294K ep:329 epch:65.80 loss:0.048 grdn:5.237 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:33:22 ot_train.py:351 step:37K smpl:296K ep:331 epch:66.16 loss:0.047 grdn:5.320 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 04:33:34 ot_train.py:351 step:37K smpl:298K ep:333 epch:66.52 loss:0.049 grdn:5.633 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:33:45 ot_train.py:351 step:37K smpl:299K ep:334 epch:66.88 loss:0.048 grdn:5.280 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:33:56 ot_train.py:351 step:38K smpl:301K ep:336 epch:67.23 loss:0.047 grdn:5.219 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:34:08 ot_train.py:351 step:38K smpl:302K ep:338 epch:67.59 loss:0.048 grdn:5.441 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:34:19 ot_train.py:351 step:38K smpl:304K ep:340 epch:67.95 loss:0.046 grdn:5.037 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:34:31 ot_train.py:351 step:38K smpl:306K ep:342 epch:68.31 loss:0.046 grdn:5.206 lr:1.0e-05 updt_s:0.053 data_s:0.006
# INFO 2025-11-12 04:34:42 ot_train.py:351 step:38K smpl:307K ep:343 epch:68.66 loss:0.046 grdn:5.239 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:34:53 ot_train.py:351 step:39K smpl:309K ep:345 epch:69.02 loss:0.046 grdn:4.892 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:35:05 ot_train.py:351 step:39K smpl:310K ep:347 epch:69.38 loss:0.046 grdn:5.213 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:35:16 ot_train.py:351 step:39K smpl:312K ep:349 epch:69.74 loss:0.045 grdn:5.198 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:35:27 ot_train.py:351 step:39K smpl:314K ep:350 epch:70.09 loss:0.045 grdn:4.806 lr:1.0e-05 updt_s:0.051 data_s:0.004
# INFO 2025-11-12 04:35:39 ot_train.py:351 step:39K smpl:315K ep:352 epch:70.45 loss:0.045 grdn:5.079 lr:1.0e-05 updt_s:0.054 data_s:0.006
# INFO 2025-11-12 04:35:51 ot_train.py:351 step:40K smpl:317K ep:354 epch:70.81 loss:0.046 grdn:4.888 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:36:02 ot_train.py:351 step:40K smpl:318K ep:356 epch:71.17 loss:0.046 grdn:5.058 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:36:13 ot_train.py:351 step:40K smpl:320K ep:358 epch:71.52 loss:0.045 grdn:5.093 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:36:13 ot_train.py:361 Checkpoint policy after step 40000
# INFO 2025-11-12 04:36:26 ot_train.py:351 step:40K smpl:322K ep:359 epch:71.88 loss:0.044 grdn:5.058 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:36:38 ot_train.py:351 step:40K smpl:323K ep:361 epch:72.24 loss:0.045 grdn:5.063 lr:1.0e-05 updt_s:0.053 data_s:0.006
# INFO 2025-11-12 04:36:50 ot_train.py:351 step:41K smpl:325K ep:363 epch:72.60 loss:0.045 grdn:4.820 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:37:01 ot_train.py:351 step:41K smpl:326K ep:365 epch:72.95 loss:0.044 grdn:4.927 lr:1.0e-05 updt_s:0.055 data_s:0.003
# INFO 2025-11-12 04:37:13 ot_train.py:351 step:41K smpl:328K ep:367 epch:73.31 loss:0.045 grdn:4.991 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:37:24 ot_train.py:351 step:41K smpl:330K ep:368 epch:73.67 loss:0.044 grdn:4.769 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:37:35 ot_train.py:351 step:41K smpl:331K ep:370 epch:74.03 loss:0.043 grdn:4.809 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:37:46 ot_train.py:351 step:42K smpl:333K ep:372 epch:74.39 loss:0.043 grdn:4.961 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 04:37:57 ot_train.py:351 step:42K smpl:334K ep:374 epch:74.74 loss:0.044 grdn:4.870 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:38:09 ot_train.py:351 step:42K smpl:336K ep:376 epch:75.10 loss:0.044 grdn:4.753 lr:1.0e-05 updt_s:0.052 data_s:0.004
# INFO 2025-11-12 04:38:20 ot_train.py:351 step:42K smpl:338K ep:377 epch:75.46 loss:0.044 grdn:4.909 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:38:31 ot_train.py:351 step:42K smpl:339K ep:379 epch:75.82 loss:0.043 grdn:4.747 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:38:43 ot_train.py:351 step:43K smpl:341K ep:381 epch:76.17 loss:0.044 grdn:4.824 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:38:54 ot_train.py:351 step:43K smpl:342K ep:383 epch:76.53 loss:0.043 grdn:4.643 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:39:05 ot_train.py:351 step:43K smpl:344K ep:384 epch:76.89 loss:0.044 grdn:4.797 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:39:17 ot_train.py:351 step:43K smpl:346K ep:386 epch:77.25 loss:0.042 grdn:4.761 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:39:28 ot_train.py:351 step:43K smpl:347K ep:388 epch:77.60 loss:0.042 grdn:4.756 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:39:39 ot_train.py:351 step:44K smpl:349K ep:390 epch:77.96 loss:0.043 grdn:4.903 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:39:51 ot_train.py:351 step:44K smpl:350K ep:392 epch:78.32 loss:0.043 grdn:4.754 lr:1.0e-05 updt_s:0.050 data_s:0.006
# INFO 2025-11-12 04:40:02 ot_train.py:351 step:44K smpl:352K ep:393 epch:78.68 loss:0.042 grdn:4.606 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:40:14 ot_train.py:351 step:44K smpl:354K ep:395 epch:79.03 loss:0.042 grdn:4.595 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:40:25 ot_train.py:351 step:44K smpl:355K ep:397 epch:79.39 loss:0.042 grdn:4.726 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:40:36 ot_train.py:351 step:45K smpl:357K ep:399 epch:79.75 loss:0.042 grdn:4.720 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:40:48 ot_train.py:351 step:45K smpl:358K ep:401 epch:80.11 loss:0.043 grdn:4.665 lr:1.0e-05 updt_s:0.052 data_s:0.004
# INFO 2025-11-12 04:41:00 ot_train.py:351 step:45K smpl:360K ep:402 epch:80.46 loss:0.041 grdn:4.395 lr:1.0e-05 updt_s:0.055 data_s:0.005
# INFO 2025-11-12 04:41:11 ot_train.py:351 step:45K smpl:362K ep:404 epch:80.82 loss:0.041 grdn:4.532 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:41:23 ot_train.py:351 step:45K smpl:363K ep:406 epch:81.18 loss:0.043 grdn:4.797 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 04:41:34 ot_train.py:351 step:46K smpl:365K ep:408 epch:81.54 loss:0.041 grdn:4.540 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:41:45 ot_train.py:351 step:46K smpl:366K ep:409 epch:81.90 loss:0.042 grdn:4.656 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:41:57 ot_train.py:351 step:46K smpl:368K ep:411 epch:82.25 loss:0.041 grdn:4.547 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:42:08 ot_train.py:351 step:46K smpl:370K ep:413 epch:82.61 loss:0.042 grdn:4.718 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:42:19 ot_train.py:351 step:46K smpl:371K ep:415 epch:82.97 loss:0.040 grdn:4.487 lr:1.0e-05 updt_s:0.055 data_s:0.003
# INFO 2025-11-12 04:42:32 ot_train.py:351 step:47K smpl:373K ep:417 epch:83.33 loss:0.041 grdn:4.460 lr:1.0e-05 updt_s:0.054 data_s:0.006
# INFO 2025-11-12 04:42:42 ot_train.py:351 step:47K smpl:374K ep:418 epch:83.68 loss:0.042 grdn:4.440 lr:1.0e-05 updt_s:0.050 data_s:0.003
# INFO 2025-11-12 04:42:54 ot_train.py:351 step:47K smpl:376K ep:420 epch:84.04 loss:0.040 grdn:4.276 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:43:05 ot_train.py:351 step:47K smpl:378K ep:422 epch:84.40 loss:0.040 grdn:4.414 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:43:16 ot_train.py:351 step:47K smpl:379K ep:424 epch:84.76 loss:0.041 grdn:4.418 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:43:27 ot_train.py:351 step:48K smpl:381K ep:426 epch:85.11 loss:0.040 grdn:4.522 lr:1.0e-05 updt_s:0.051 data_s:0.004
# INFO 2025-11-12 04:43:40 ot_train.py:351 step:48K smpl:382K ep:427 epch:85.47 loss:0.040 grdn:4.406 lr:1.0e-05 updt_s:0.055 data_s:0.006
# INFO 2025-11-12 04:43:51 ot_train.py:351 step:48K smpl:384K ep:429 epch:85.83 loss:0.040 grdn:4.432 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:44:02 ot_train.py:351 step:48K smpl:386K ep:431 epch:86.19 loss:0.040 grdn:4.223 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:44:13 ot_train.py:351 step:48K smpl:387K ep:433 epch:86.54 loss:0.040 grdn:4.402 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:44:25 ot_train.py:351 step:49K smpl:389K ep:435 epch:86.90 loss:0.041 grdn:4.396 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:44:36 ot_train.py:351 step:49K smpl:390K ep:436 epch:87.26 loss:0.039 grdn:4.228 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:44:48 ot_train.py:351 step:49K smpl:392K ep:438 epch:87.62 loss:0.039 grdn:4.345 lr:1.0e-05 updt_s:0.054 data_s:0.003
# INFO 2025-11-12 04:44:59 ot_train.py:351 step:49K smpl:394K ep:440 epch:87.97 loss:0.039 grdn:4.296 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:45:11 ot_train.py:351 step:49K smpl:395K ep:442 epch:88.33 loss:0.040 grdn:4.538 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:45:22 ot_train.py:351 step:50K smpl:397K ep:443 epch:88.69 loss:0.040 grdn:4.329 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:45:33 ot_train.py:351 step:50K smpl:398K ep:445 epch:89.05 loss:0.039 grdn:4.186 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:45:45 ot_train.py:351 step:50K smpl:400K ep:447 epch:89.41 loss:0.038 grdn:4.316 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 04:45:56 ot_train.py:351 step:50K smpl:402K ep:449 epch:89.76 loss:0.040 grdn:4.343 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:46:07 ot_train.py:351 step:50K smpl:403K ep:451 epch:90.12 loss:0.039 grdn:4.297 lr:1.0e-05 updt_s:0.052 data_s:0.004
# INFO 2025-11-12 04:46:19 ot_train.py:351 step:51K smpl:405K ep:452 epch:90.48 loss:0.038 grdn:4.126 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:46:30 ot_train.py:351 step:51K smpl:406K ep:454 epch:90.84 loss:0.039 grdn:4.170 lr:1.0e-05 updt_s:0.050 data_s:0.003
# INFO 2025-11-12 04:46:42 ot_train.py:351 step:51K smpl:408K ep:456 epch:91.19 loss:0.039 grdn:4.378 lr:1.0e-05 updt_s:0.055 data_s:0.006
# INFO 2025-11-12 04:46:53 ot_train.py:351 step:51K smpl:410K ep:458 epch:91.55 loss:0.040 grdn:4.308 lr:1.0e-05 updt_s:0.050 data_s:0.003
# INFO 2025-11-12 04:47:04 ot_train.py:351 step:51K smpl:411K ep:460 epch:91.91 loss:0.044 grdn:4.283 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:47:16 ot_train.py:351 step:52K smpl:413K ep:461 epch:92.27 loss:0.039 grdn:4.028 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 04:47:27 ot_train.py:351 step:52K smpl:414K ep:463 epch:92.62 loss:0.042 grdn:4.135 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:47:38 ot_train.py:351 step:52K smpl:416K ep:465 epch:92.98 loss:0.040 grdn:3.996 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:47:49 ot_train.py:351 step:52K smpl:418K ep:467 epch:93.34 loss:0.039 grdn:4.199 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 04:48:01 ot_train.py:351 step:52K smpl:419K ep:468 epch:93.70 loss:0.038 grdn:4.018 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:48:12 ot_train.py:351 step:53K smpl:421K ep:470 epch:94.05 loss:0.037 grdn:3.941 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:48:23 ot_train.py:351 step:53K smpl:422K ep:472 epch:94.41 loss:0.038 grdn:4.200 lr:1.0e-05 updt_s:0.053 data_s:0.006
# INFO 2025-11-12 04:48:35 ot_train.py:351 step:53K smpl:424K ep:474 epch:94.77 loss:0.037 grdn:3.930 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:48:46 ot_train.py:351 step:53K smpl:426K ep:476 epch:95.13 loss:0.038 grdn:4.127 lr:1.0e-05 updt_s:0.051 data_s:0.004
# INFO 2025-11-12 04:48:57 ot_train.py:351 step:53K smpl:427K ep:477 epch:95.49 loss:0.037 grdn:4.062 lr:1.0e-05 updt_s:0.054 data_s:0.006
# INFO 2025-11-12 04:49:08 ot_train.py:351 step:54K smpl:429K ep:479 epch:95.84 loss:0.037 grdn:4.083 lr:1.0e-05 updt_s:0.050 data_s:0.003
# INFO 2025-11-12 04:49:20 ot_train.py:351 step:54K smpl:430K ep:481 epch:96.20 loss:0.037 grdn:4.068 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 04:49:31 ot_train.py:351 step:54K smpl:432K ep:483 epch:96.56 loss:0.038 grdn:4.174 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:49:42 ot_train.py:351 step:54K smpl:434K ep:485 epch:96.92 loss:0.037 grdn:3.932 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:49:54 ot_train.py:351 step:54K smpl:435K ep:486 epch:97.27 loss:0.037 grdn:4.045 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 04:50:05 ot_train.py:351 step:55K smpl:437K ep:488 epch:97.63 loss:0.037 grdn:3.919 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:50:16 ot_train.py:351 step:55K smpl:438K ep:490 epch:97.99 loss:0.038 grdn:3.948 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:50:28 ot_train.py:351 step:55K smpl:440K ep:492 epch:98.35 loss:0.036 grdn:3.902 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:50:39 ot_train.py:351 step:55K smpl:442K ep:494 epch:98.70 loss:0.036 grdn:3.906 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:50:50 ot_train.py:351 step:55K smpl:443K ep:495 epch:99.06 loss:0.037 grdn:3.878 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:51:02 ot_train.py:351 step:56K smpl:445K ep:497 epch:99.42 loss:0.036 grdn:3.945 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:51:13 ot_train.py:351 step:56K smpl:446K ep:499 epch:99.78 loss:0.036 grdn:3.866 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:51:24 ot_train.py:351 step:56K smpl:448K ep:501 epch:100.13 loss:0.037 grdn:3.984 lr:1.0e-05 updt_s:0.051 data_s:0.004
# INFO 2025-11-12 04:51:36 ot_train.py:351 step:56K smpl:450K ep:502 epch:100.49 loss:0.037 grdn:3.998 lr:1.0e-05 updt_s:0.053 data_s:0.005
# INFO 2025-11-12 04:51:47 ot_train.py:351 step:56K smpl:451K ep:504 epch:100.85 loss:0.036 grdn:3.881 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:51:58 ot_train.py:351 step:57K smpl:453K ep:506 epch:101.21 loss:0.037 grdn:4.162 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 04:52:09 ot_train.py:351 step:57K smpl:454K ep:508 epch:101.56 loss:0.036 grdn:3.812 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:52:20 ot_train.py:351 step:57K smpl:456K ep:510 epch:101.92 loss:0.036 grdn:3.756 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:52:32 ot_train.py:351 step:57K smpl:458K ep:511 epch:102.28 loss:0.036 grdn:3.924 lr:1.0e-05 updt_s:0.053 data_s:0.006
# INFO 2025-11-12 04:52:43 ot_train.py:351 step:57K smpl:459K ep:513 epch:102.64 loss:0.035 grdn:3.653 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 04:52:55 ot_train.py:351 step:58K smpl:461K ep:515 epch:103.00 loss:0.036 grdn:3.882 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 04:53:06 ot_train.py:351 step:58K smpl:462K ep:517 epch:103.35 loss:0.036 grdn:3.898 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 04:53:17 ot_train.py:351 step:58K smpl:464K ep:519 epch:103.71 loss:0.035 grdn:3.679 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 04:53:29 ot_train.py:351 step:58K smpl:466K ep:520 epch:104.07 loss:0.035 grdn:3.880 lr:1.0e-05 updt_s:0.051 data_s:0.003
# ...
# INFO 2025-11-12 05:11:43 ot_train.py:351 step:77K smpl:619K ep:692 epch:138.40 loss:0.030 grdn:3.153 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 05:11:54 ot_train.py:351 step:78K smpl:621K ep:694 epch:138.76 loss:0.030 grdn:2.951 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:12:05 ot_train.py:351 step:78K smpl:622K ep:696 epch:139.11 loss:0.030 grdn:3.040 lr:1.0e-05 updt_s:0.050 data_s:0.003
# INFO 2025-11-12 05:12:16 ot_train.py:351 step:78K smpl:624K ep:697 epch:139.47 loss:0.030 grdn:3.185 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 05:12:27 ot_train.py:351 step:78K smpl:626K ep:699 epch:139.83 loss:0.030 grdn:3.079 lr:1.0e-05 updt_s:0.050 data_s:0.003
# INFO 2025-11-12 05:12:38 ot_train.py:351 step:78K smpl:627K ep:701 epch:140.19 loss:0.029 grdn:3.039 lr:1.0e-05 updt_s:0.053 data_s:0.004
# INFO 2025-11-12 05:12:50 ot_train.py:351 step:79K smpl:629K ep:703 epch:140.55 loss:0.029 grdn:2.991 lr:1.0e-05 updt_s:0.054 data_s:0.005
# INFO 2025-11-12 05:13:01 ot_train.py:351 step:79K smpl:630K ep:705 epch:140.90 loss:0.029 grdn:2.954 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:13:13 ot_train.py:351 step:79K smpl:632K ep:706 epch:141.26 loss:0.029 grdn:3.061 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 05:13:24 ot_train.py:351 step:79K smpl:634K ep:708 epch:141.62 loss:0.029 grdn:3.073 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:13:35 ot_train.py:351 step:79K smpl:635K ep:710 epch:141.98 loss:0.029 grdn:2.953 lr:1.0e-05 updt_s:0.050 data_s:0.003
# INFO 2025-11-12 05:13:46 ot_train.py:351 step:80K smpl:637K ep:712 epch:142.33 loss:0.029 grdn:3.001 lr:1.0e-05 updt_s:0.050 data_s:0.006
# INFO 2025-11-12 05:13:58 ot_train.py:351 step:80K smpl:638K ep:713 epch:142.69 loss:0.029 grdn:2.873 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 05:14:09 ot_train.py:351 step:80K smpl:640K ep:715 epch:143.05 loss:0.029 grdn:2.978 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 05:14:09 ot_train.py:361 Checkpoint policy after step 80000
# INFO 2025-11-12 05:14:23 ot_train.py:351 step:80K smpl:642K ep:717 epch:143.41 loss:0.028 grdn:2.869 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 05:14:34 ot_train.py:351 step:80K smpl:643K ep:719 epch:143.76 loss:0.029 grdn:2.996 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:14:45 ot_train.py:351 step:81K smpl:645K ep:721 epch:144.12 loss:0.029 grdn:3.052 lr:1.0e-05 updt_s:0.054 data_s:0.003
# INFO 2025-11-12 05:14:57 ot_train.py:351 step:81K smpl:646K ep:722 epch:144.48 loss:0.029 grdn:3.046 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 05:15:08 ot_train.py:351 step:81K smpl:648K ep:724 epch:144.84 loss:0.029 grdn:2.965 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 05:15:20 ot_train.py:351 step:81K smpl:650K ep:726 epch:145.19 loss:0.029 grdn:2.971 lr:1.0e-05 updt_s:0.055 data_s:0.004
# INFO 2025-11-12 05:15:32 ot_train.py:351 step:81K smpl:651K ep:728 epch:145.55 loss:0.029 grdn:2.907 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 05:15:43 ot_train.py:351 step:82K smpl:653K ep:730 epch:145.91 loss:0.030 grdn:2.954 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 05:15:54 ot_train.py:351 step:82K smpl:654K ep:731 epch:146.27 loss:0.030 grdn:3.060 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 05:16:06 ot_train.py:351 step:82K smpl:656K ep:733 epch:146.62 loss:0.029 grdn:2.950 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 05:16:17 ot_train.py:351 step:82K smpl:658K ep:735 epch:146.98 loss:0.029 grdn:3.081 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 05:16:28 ot_train.py:351 step:82K smpl:659K ep:737 epch:147.34 loss:0.028 grdn:2.930 lr:1.0e-05 updt_s:0.050 data_s:0.006
# INFO 2025-11-12 05:16:39 ot_train.py:351 step:83K smpl:661K ep:738 epch:147.70 loss:0.028 grdn:2.904 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:16:50 ot_train.py:351 step:83K smpl:662K ep:740 epch:148.06 loss:0.029 grdn:2.903 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:17:02 ot_train.py:351 step:83K smpl:664K ep:742 epch:148.41 loss:0.029 grdn:3.019 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 05:17:13 ot_train.py:351 step:83K smpl:666K ep:744 epch:148.77 loss:0.029 grdn:3.052 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:17:24 ot_train.py:351 step:83K smpl:667K ep:746 epch:149.13 loss:0.028 grdn:2.828 lr:1.0e-05 updt_s:0.054 data_s:0.003
# INFO 2025-11-12 05:17:36 ot_train.py:351 step:84K smpl:669K ep:747 epch:149.49 loss:0.028 grdn:2.976 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 05:17:47 ot_train.py:351 step:84K smpl:670K ep:749 epch:149.84 loss:0.028 grdn:2.957 lr:1.0e-05 updt_s:0.050 data_s:0.003
# INFO 2025-11-12 05:17:58 ot_train.py:351 step:84K smpl:672K ep:751 epch:150.20 loss:0.028 grdn:2.827 lr:1.0e-05 updt_s:0.052 data_s:0.004
# INFO 2025-11-12 05:18:10 ot_train.py:351 step:84K smpl:674K ep:753 epch:150.56 loss:0.028 grdn:3.028 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 05:18:20 ot_train.py:351 step:84K smpl:675K ep:755 epch:150.92 loss:0.028 grdn:2.878 lr:1.0e-05 updt_s:0.050 data_s:0.003
# INFO 2025-11-12 05:18:32 ot_train.py:351 step:85K smpl:677K ep:756 epch:151.27 loss:0.028 grdn:2.811 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 05:18:43 ot_train.py:351 step:85K smpl:678K ep:758 epch:151.63 loss:0.028 grdn:2.787 lr:1.0e-05 updt_s:0.050 data_s:0.003
# INFO 2025-11-12 05:18:54 ot_train.py:351 step:85K smpl:680K ep:760 epch:151.99 loss:0.028 grdn:3.010 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:19:06 ot_train.py:351 step:85K smpl:682K ep:762 epch:152.35 loss:0.028 grdn:3.010 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 05:19:17 ot_train.py:351 step:85K smpl:683K ep:764 epch:152.70 loss:0.028 grdn:2.981 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 05:19:28 ot_train.py:351 step:86K smpl:685K ep:765 epch:153.06 loss:0.028 grdn:2.740 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:19:40 ot_train.py:351 step:86K smpl:686K ep:767 epch:153.42 loss:0.028 grdn:2.871 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 05:19:51 ot_train.py:351 step:86K smpl:688K ep:769 epch:153.78 loss:0.028 grdn:2.911 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 05:20:02 ot_train.py:351 step:86K smpl:690K ep:771 epch:154.14 loss:0.028 grdn:2.790 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:20:13 ot_train.py:351 step:86K smpl:691K ep:772 epch:154.49 loss:0.028 grdn:2.784 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 05:20:24 ot_train.py:351 step:87K smpl:693K ep:774 epch:154.85 loss:0.028 grdn:2.880 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 05:20:36 ot_train.py:351 step:87K smpl:694K ep:776 epch:155.21 loss:0.028 grdn:2.771 lr:1.0e-05 updt_s:0.053 data_s:0.004
# INFO 2025-11-12 05:20:47 ot_train.py:351 step:87K smpl:696K ep:778 epch:155.57 loss:0.028 grdn:2.790 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 05:20:59 ot_train.py:351 step:87K smpl:698K ep:780 epch:155.92 loss:0.027 grdn:2.773 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:21:10 ot_train.py:351 step:87K smpl:699K ep:781 epch:156.28 loss:0.028 grdn:2.829 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 05:21:22 ot_train.py:351 step:88K smpl:701K ep:783 epch:156.64 loss:0.027 grdn:2.721 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:21:32 ot_train.py:351 step:88K smpl:702K ep:785 epch:157.00 loss:0.027 grdn:2.776 lr:1.0e-05 updt_s:0.050 data_s:0.003
# INFO 2025-11-12 05:21:44 ot_train.py:351 step:88K smpl:704K ep:787 epch:157.35 loss:0.028 grdn:2.906 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 05:21:55 ot_train.py:351 step:88K smpl:706K ep:789 epch:157.71 loss:0.027 grdn:2.754 lr:1.0e-05 updt_s:0.054 data_s:0.003
# INFO 2025-11-12 05:22:06 ot_train.py:351 step:88K smpl:707K ep:790 epch:158.07 loss:0.027 grdn:2.764 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:22:18 ot_train.py:351 step:89K smpl:709K ep:792 epch:158.43 loss:0.027 grdn:2.813 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 05:22:29 ot_train.py:351 step:89K smpl:710K ep:794 epch:158.78 loss:0.028 grdn:2.789 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 05:22:41 ot_train.py:351 step:89K smpl:712K ep:796 epch:159.14 loss:0.027 grdn:2.788 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:22:52 ot_train.py:351 step:89K smpl:714K ep:797 epch:159.50 loss:0.027 grdn:2.799 lr:1.0e-05 updt_s:0.053 data_s:0.006
# INFO 2025-11-12 05:23:03 ot_train.py:351 step:89K smpl:715K ep:799 epch:159.86 loss:0.027 grdn:2.790 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 05:23:15 ot_train.py:351 step:90K smpl:717K ep:801 epch:160.21 loss:0.028 grdn:2.816 lr:1.0e-05 updt_s:0.053 data_s:0.004
# INFO 2025-11-12 05:23:27 ot_train.py:351 step:90K smpl:718K ep:803 epch:160.57 loss:0.027 grdn:2.787 lr:1.0e-05 updt_s:0.054 data_s:0.006
# INFO 2025-11-12 05:23:38 ot_train.py:351 step:90K smpl:720K ep:805 epch:160.93 loss:0.027 grdn:2.663 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:23:50 ot_train.py:351 step:90K smpl:722K ep:806 epch:161.29 loss:0.027 grdn:2.836 lr:1.0e-05 updt_s:0.053 data_s:0.006
# INFO 2025-11-12 05:24:01 ot_train.py:351 step:90K smpl:723K ep:808 epch:161.65 loss:0.028 grdn:2.838 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:24:12 ot_train.py:351 step:91K smpl:725K ep:810 epch:162.00 loss:0.027 grdn:2.694 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:24:24 ot_train.py:351 step:91K smpl:726K ep:812 epch:162.36 loss:0.027 grdn:2.645 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 05:24:35 ot_train.py:351 step:91K smpl:728K ep:814 epch:162.72 loss:0.027 grdn:2.700 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 05:24:47 ot_train.py:351 step:91K smpl:730K ep:815 epch:163.08 loss:0.027 grdn:2.758 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 05:24:59 ot_train.py:351 step:91K smpl:731K ep:817 epch:163.43 loss:0.027 grdn:2.665 lr:1.0e-05 updt_s:0.055 data_s:0.006
# INFO 2025-11-12 05:25:10 ot_train.py:351 step:92K smpl:733K ep:819 epch:163.79 loss:0.027 grdn:2.736 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 05:25:21 ot_train.py:351 step:92K smpl:734K ep:821 epch:164.15 loss:0.026 grdn:2.705 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:25:33 ot_train.py:351 step:92K smpl:736K ep:823 epch:164.51 loss:0.027 grdn:2.813 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 05:25:44 ot_train.py:351 step:92K smpl:738K ep:824 epch:164.86 loss:0.026 grdn:2.696 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:25:55 ot_train.py:351 step:92K smpl:739K ep:826 epch:165.22 loss:0.027 grdn:2.671 lr:1.0e-05 updt_s:0.053 data_s:0.004
# INFO 2025-11-12 05:26:07 ot_train.py:351 step:93K smpl:741K ep:828 epch:165.58 loss:0.027 grdn:2.740 lr:1.0e-05 updt_s:0.052 data_s:0.005
# INFO 2025-11-12 05:26:18 ot_train.py:351 step:93K smpl:742K ep:830 epch:165.94 loss:0.026 grdn:2.607 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:26:30 ot_train.py:351 step:93K smpl:744K ep:831 epch:166.29 loss:0.027 grdn:2.655 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 05:26:41 ot_train.py:351 step:93K smpl:746K ep:833 epch:166.65 loss:0.027 grdn:2.745 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:26:52 ot_train.py:351 step:93K smpl:747K ep:835 epch:167.01 loss:0.026 grdn:2.637 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 05:27:04 ot_train.py:351 step:94K smpl:749K ep:837 epch:167.37 loss:0.026 grdn:2.617 lr:1.0e-05 updt_s:0.053 data_s:0.006
# INFO 2025-11-12 05:27:15 ot_train.py:351 step:94K smpl:750K ep:839 epch:167.72 loss:0.027 grdn:2.712 lr:1.0e-05 updt_s:0.055 data_s:0.003
# INFO 2025-11-12 05:27:27 ot_train.py:351 step:94K smpl:752K ep:840 epch:168.08 loss:0.027 grdn:2.657 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 05:27:38 ot_train.py:351 step:94K smpl:754K ep:842 epch:168.44 loss:0.028 grdn:2.772 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 05:27:49 ot_train.py:351 step:94K smpl:755K ep:844 epch:168.80 loss:0.026 grdn:2.673 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:28:00 ot_train.py:351 step:95K smpl:757K ep:846 epch:169.16 loss:0.026 grdn:2.608 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 05:28:12 ot_train.py:351 step:95K smpl:758K ep:848 epch:169.51 loss:0.026 grdn:2.756 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 05:28:23 ot_train.py:351 step:95K smpl:760K ep:849 epch:169.87 loss:0.026 grdn:2.623 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 05:28:35 ot_train.py:351 step:95K smpl:762K ep:851 epch:170.23 loss:0.026 grdn:2.684 lr:1.0e-05 updt_s:0.053 data_s:0.004
# INFO 2025-11-12 05:28:46 ot_train.py:351 step:95K smpl:763K ep:853 epch:170.59 loss:0.026 grdn:2.656 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 05:28:57 ot_train.py:351 step:96K smpl:765K ep:855 epch:170.94 loss:0.026 grdn:2.482 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 05:29:09 ot_train.py:351 step:96K smpl:766K ep:857 epch:171.30 loss:0.026 grdn:2.704 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 05:29:20 ot_train.py:351 step:96K smpl:768K ep:858 epch:171.66 loss:0.026 grdn:2.588 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:29:31 ot_train.py:351 step:96K smpl:770K ep:860 epch:172.02 loss:0.026 grdn:2.694 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:29:43 ot_train.py:351 step:96K smpl:771K ep:862 epch:172.37 loss:0.026 grdn:2.666 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 05:29:54 ot_train.py:351 step:97K smpl:773K ep:864 epch:172.73 loss:0.026 grdn:2.483 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:30:05 ot_train.py:351 step:97K smpl:774K ep:865 epch:173.09 loss:0.026 grdn:2.695 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 05:30:17 ot_train.py:351 step:97K smpl:776K ep:867 epch:173.45 loss:0.026 grdn:2.622 lr:1.0e-05 updt_s:0.054 data_s:0.006
# INFO 2025-11-12 05:30:28 ot_train.py:351 step:97K smpl:778K ep:869 epch:173.80 loss:0.026 grdn:2.616 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 05:30:39 ot_train.py:351 step:97K smpl:779K ep:871 epch:174.16 loss:0.026 grdn:2.626 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 05:30:51 ot_train.py:351 step:98K smpl:781K ep:873 epch:174.52 loss:0.026 grdn:2.606 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 05:31:02 ot_train.py:351 step:98K smpl:782K ep:874 epch:174.88 loss:0.026 grdn:2.566 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 05:31:13 ot_train.py:351 step:98K smpl:784K ep:876 epch:175.23 loss:0.026 grdn:2.655 lr:1.0e-05 updt_s:0.052 data_s:0.004
# INFO 2025-11-12 05:31:25 ot_train.py:351 step:98K smpl:786K ep:878 epch:175.59 loss:0.025 grdn:2.530 lr:1.0e-05 updt_s:0.054 data_s:0.006
# INFO 2025-11-12 05:31:36 ot_train.py:351 step:98K smpl:787K ep:880 epch:175.95 loss:0.026 grdn:2.520 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 05:31:48 ot_train.py:351 step:99K smpl:789K ep:882 epch:176.31 loss:0.026 grdn:2.629 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 05:31:59 ot_train.py:351 step:99K smpl:790K ep:883 epch:176.67 loss:0.025 grdn:2.546 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:32:10 ot_train.py:351 step:99K smpl:792K ep:885 epch:177.02 loss:0.026 grdn:2.552 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 05:32:22 ot_train.py:351 step:99K smpl:794K ep:887 epch:177.38 loss:0.026 grdn:2.589 lr:1.0e-05 updt_s:0.051 data_s:0.006
# INFO 2025-11-12 05:32:33 ot_train.py:351 step:99K smpl:795K ep:889 epch:177.74 loss:0.026 grdn:2.592 lr:1.0e-05 updt_s:0.053 data_s:0.003
# INFO 2025-11-12 05:32:44 ot_train.py:351 step:100K smpl:797K ep:890 epch:178.10 loss:0.025 grdn:2.515 lr:1.0e-05 updt_s:0.051 data_s:0.003
# INFO 2025-11-12 05:32:56 ot_train.py:351 step:100K smpl:798K ep:892 epch:178.45 loss:0.025 grdn:2.518 lr:1.0e-05 updt_s:0.052 data_s:0.006
# INFO 2025-11-12 05:33:07 ot_train.py:351 step:100K smpl:800K ep:894 epch:178.81 loss:0.025 grdn:2.486 lr:1.0e-05 updt_s:0.052 data_s:0.003
# INFO 2025-11-12 05:33:07 ot_train.py:361 Checkpoint policy after step 100000
# INFO 2025-11-12 05:33:09 ot_train.py:430 End of training

# %% [markdown]
# ## Login into Hugging Face Hub
# Now after training is done login into the Hugging Face hub and upload the last checkpoint

# %%
# !huggingface-cli login
# Out:
# ⚠️  Warning: 'huggingface-cli login' is deprecated. Use 'hf auth login' instead.
#
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `hf auth whoami` to get more information or `hf auth logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: write).
# The token `robot_traindata` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `robot_traindata`

# %%
# !huggingface-cli upload berobemin/record-test2 \
  /content/lerobot/outputs/train/act_record_test2/checkpoints/last/pretrained_model
# Out:
# ⚠️  Warning: 'huggingface-cli upload' is deprecated. Use 'hf upload' instead.
# Start hashing 7 files.
# Finished hashing 7 files.
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#   ...d_model/model.safetensors:   0% 563k/207M [00:00<?, ?B/s]
#
# Processing Files (0 / 1)      :   0% 563k/207M [00:01<06:08, 560kB/s,  703kB/s  ]
# New Data Upload               :   1% 563k/67.1M [00:01<01:58, 560kB/s,  703kB/s  ]
#
#   ...d_model/model.safetensors:   0% 563k/207M [00:00<?, ?B/s]
#
# Processing Files (0 / 1)      :   2% 4.50M/207M [00:01<00:51, 3.93MB/s, 3.75MB/s  ]
# New Data Upload               :   3% 4.50M/134M [00:01<00:32, 3.93MB/s, 3.75MB/s  ]
#
# Processing Files (0 / 1)      :   3% 6.75M/207M [00:01<00:36, 5.43MB/s, 4.82MB/s  ]
# New Data Upload               :   5% 6.75M/134M [00:01<00:23, 5.43MB/s, 4.82MB/s  ]
#
# Processing Files (0 / 1)      :   7% 14.6M/207M [00:01<00:14, 13.1MB/s, 9.13MB/s  ]
# New Data Upload               :   7% 14.6M/201M [00:01<00:14, 13.1MB/s, 9.13MB/s  ]
#
# Processing Files (0 / 1)      :  12% 24.7M/207M [00:02<00:08, 22.3MB/s, 13.7MB/s  ]
# New Data Upload               :  12% 24.7M/207M [00:02<00:08, 22.3MB/s, 13.7MB/s  ]
#
#
#   ...zer_processor.safetensors:  10% 666/6.62k [00:00<?, ?B/s]
#
#
#
#   ...zer_processor.safetensors:  10% 666/6.62k [00:00<?, ?B/s]
#
#   ...d_model/model.safetensors:  18% 38.2M/207M [00:01<00:05, 31.3MB/s]
#
#
#   ...zer_processor.safetensors:  10% 666/6.62k [00:00<?, ?B/s]
#
#
#
# Processing Files (0 / 3)      :  18% 38.2M/207M [00:02<00:04, 33.9MB/s, 19.1MB/s  ]
# New Data Upload               :  18% 38.2M/207M [00:02<00:04, 33.9MB/s, 19.1MB/s  ]
#
#   ...d_model/model.safetensors:  28% 58.9M/207M [00:01<00:03, 41.7MB/s]
#
#
#   ...zer_processor.safetensors:  20% 1.33k/6.62k [00:00<00:01, 3.34kB/s]
#
#
#
# Processing Files (0 / 3)      :  28% 58.9M/207M [00:02<00:02, 52.8MB/s, 26.8MB/s  ]
# New Data Upload               :  28% 58.9M/207M [00:02<00:02, 52.8MB/s, 26.8MB/s  ]
#
#   ...d_model/model.safetensors:  38% 78.5M/207M [00:01<00:02, 48.7MB/s]
#
#
#   ...zer_processor.safetensors:  80% 5.33k/6.62k [00:00<00:00, 11.7kB/s]
#
#
#
# Processing Files (0 / 3)      :  38% 78.5M/207M [00:02<00:01, 65.4MB/s, 32.7MB/s  ]
# New Data Upload               :  38% 78.5M/207M [00:02<00:01, 65.4MB/s, 32.7MB/s  ]
#
#   ...d_model/model.safetensors:  48% 99.2M/207M [00:01<00:01, 54.8MB/s]
#
#
#   ...zer_processor.safetensors:  91% 6.00k/6.62k [00:00<00:00, 8.88kB/s]
#
#
#
# Processing Files (0 / 3)      :  48% 99.2M/207M [00:02<00:01, 76.1MB/s, 38.1MB/s  ]
# New Data Upload               :  48% 99.2M/207M [00:02<00:01, 76.1MB/s, 38.1MB/s  ]
#
#   ...d_model/model.safetensors:  59% 121M/207M [00:01<00:01, 60.2MB/s]
#
#
#   ...zer_processor.safetensors:  91% 6.00k/6.62k [00:00<00:00, 6.67kB/s]
#
#
#
# Processing Files (0 / 3)      :  59% 121M/207M [00:03<00:01, 85.7MB/s, 43.2MB/s  ]
# New Data Upload               :  59% 121M/207M [00:03<00:01, 85.7MB/s, 43.2MB/s  ]
#
#   ...d_model/model.safetensors:  70% 144M/207M [00:02<00:00, 65.4MB/s]
#
#
#   ...zer_processor.safetensors: 100% 6.62k/6.62k [00:00<00:00, 5.96kB/s]
#
#
#
# Processing Files (2 / 3)      :  70% 144M/207M [00:03<00:00, 95.0MB/s, 48.2MB/s  ]
# New Data Upload               :  70% 144M/207M [00:03<00:00, 95.0MB/s, 48.2MB/s  ]
#
#   ...d_model/model.safetensors:  78% 161M/207M [00:02<00:00, 66.7MB/s]
#
#
#   ...zer_processor.safetensors: 100% 6.62k/6.62k [00:01<00:00, 4.96kB/s]
#
#
#
# Processing Files (2 / 3)      :  78% 161M/207M [00:03<00:00, 90.8MB/s, 50.2MB/s  ]
# New Data Upload               :  78% 161M/207M [00:03<00:00, 90.8MB/s, 50.2MB/s  ]
#
#   ...d_model/model.safetensors:  86% 177M/207M [00:02<00:00, 68.0MB/s]
#
#
#   ...zer_processor.safetensors: 100% 6.62k/6.62k [00:01<00:00, 4.25kB/s]
#
#
#
# Processing Files (2 / 3)      :  86% 177M/207M [00:03<00:00, 88.6MB/s, 52.1MB/s  ]
# New Data Upload               :  86% 177M/207M [00:03<00:00, 88.6MB/s, 52.1MB/s  ]
#
#   ...d_model/model.safetensors:  92% 190M/207M [00:02<00:00, 67.5MB/s]
#
#
#   ...zer_processor.safetensors: 100% 6.62k/6.62k [00:01<00:00, 3.72kB/s]
#
#
#
# Processing Files (2 / 3)      :  92% 190M/207M [00:03<00:00, 80.5MB/s, 52.7MB/s  ]
# New Data Upload               :  92% 190M/207M [00:03<00:00, 80.5MB/s, 52.7MB/s  ]
#
#   ...d_model/model.safetensors:  95% 196M/207M [00:02<00:00, 65.2MB/s]
#
#
#   ...zer_processor.safetensors: 100% 6.62k/6.62k [00:01<00:00, 3.31kB/s]
#
#
#
# Processing Files (2 / 3)      :  95% 196M/207M [00:04<00:00, 66.5MB/s, 51.6MB/s  ]
# New Data Upload               :  95% 196M/207M [00:04<00:00, 66.5MB/s, 51.6MB/s  ]
#
#   ...d_model/model.safetensors:  98% 203M/207M [00:03<00:00, 63.2MB/s]
#
#
#   ...zer_processor.safetensors: 100% 6.62k/6.62k [00:02<00:00, 2.98kB/s]
#
#
#
# Processing Files (2 / 3)      :  98% 203M/207M [00:04<00:00, 56.6MB/s, 50.7MB/s  ]
# New Data Upload               :  98% 203M/207M [00:04<00:00, 56.6MB/s, 50.7MB/s  ]
#
#   ...d_model/model.safetensors: 100% 206M/207M [00:03<00:00, 60.5MB/s]
#
#
#   ...zer_processor.safetensors: 100% 6.62k/6.62k [00:02<00:00, 2.71kB/s]
#
#
#
# Processing Files (2 / 3)      : 100% 206M/207M [00:04<00:00, 44.7MB/s, 49.1MB/s  ]
# New Data Upload               : 100% 206M/207M [00:04<00:00, 44.7MB/s, 49.1MB/s  ]
#
#   ...d_model/model.safetensors: 100% 206M/207M [00:03<00:00, 57.2MB/s]
#
#
#   ...zer_processor.safetensors: 100% 6.62k/6.62k [00:02<00:00, 2.48kB/s]
#
#
#
# Processing Files (2 / 3)      : 100% 206M/207M [00:04<00:00, 31.5MB/s, 46.9MB/s  ]
# New Data Upload               : 100% 206M/207M [00:04<00:00, 31.5MB/s, 46.9MB/s  ]
#
#   ...d_model/model.safetensors: 100% 207M/207M [00:03<00:00, 54.2MB/s]
#
#
#   ...zer_processor.safetensors: 100% 6.62k/6.62k [00:02<00:00, 2.29kB/s]
#
#
#
# Processing Files (2 / 3)      : 100% 207M/207M [00:04<00:00, 22.2MB/s, 44.9MB/s  ]
# New Data Upload               : 100% 207M/207M [00:04<00:00, 22.2MB/s, 44.9MB/s  ]
#
#   ...d_model/model.safetensors: 100% 207M/207M [00:03<00:00, 51.5MB/s]
#
#
#   ...zer_processor.safetensors: 100% 6.62k/6.62k [00:02<00:00, 2.13kB/s]
#
#
#
#   ...zer_processor.safetensors: 100% 6.62k/6.62k [00:02<00:00, 2.13kB/s]
#
#   ...d_model/model.safetensors: 100% 207M/207M [00:04<00:00, 49.1MB/s]
#
#
#   ...zer_processor.safetensors: 100% 6.62k/6.62k [00:03<00:00, 1.99kB/s]
#
#
#
# Processing Files (3 / 3)      : 100% 207M/207M [00:05<00:00, 12.2MB/s, 41.3MB/s  ]
# New Data Upload               : 100% 207M/207M [00:05<00:00, 12.2MB/s, 41.3MB/s  ]
#
#   ...d_model/model.safetensors: 100% 207M/207M [00:04<00:00, 46.9MB/s]
#
#
#   ...zer_processor.safetensors: 100% 6.62k/6.62k [00:03<00:00, 1.86kB/s]
#
#
#
#   ...zer_processor.safetensors: 100% 6.62k/6.62k [00:03<00:00, 1.86kB/s]
#
#   ...d_model/model.safetensors: 100% 207M/207M [00:04<00:00, 46.6MB/s]
#
#
#   ...zer_processor.safetensors: 100% 6.62k/6.62k [00:03<00:00, 1.85kB/s]
#
#
#
#   ...zer_processor.safetensors: 100% 6.62k/6.62k [00:03<00:00, 1.85kB/s]
#
#   ...d_model/model.safetensors: 100% 207M/207M [00:04<00:00, 44.8MB/s]
#
#
#   ...zer_processor.safetensors: 100% 6.62k/6.62k [00:03<00:00, 1.75kB/s]
#
#
#
# Processing Files (3 / 3)      : 100% 207M/207M [00:05<00:00, 36.9MB/s, 38.3MB/s  ]
# New Data Upload               : 100% 207M/207M [00:05<00:00, 36.9MB/s, 38.3MB/s  ]
#   ...d_model/model.safetensors: 100% 207M/207M [00:04<00:00, 44.8MB/s]
#   ...zer_processor.safetensors: 100% 6.62k/6.62k [00:03<00:00, 1.75kB/s]
#   ...zer_processor.safetensors: 100% 6.62k/6.62k [00:03<00:00, 1.75kB/s]
# https://huggingface.co/berobemin/record-test2/tree/main/.
